# %%
# Import necessary libraries
import numpy as np
import scipy.interpolate as spi
import matplotlib.pyplot as plt

# %%
# Example 1: Linear Interpolation with interp1d
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create a linear interpolation function
linear_interp = spi.interp1d(x, y, kind='linear')

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = linear_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Linear Interpolation')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Linear Interpolation of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 2: Cubic Spline Interpolation with interp1d
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create a cubic spline interpolation function
cubic_interp = spi.interp1d(x, y, kind='cubic')

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = cubic_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Cubic Spline Interpolation')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Cubic Spline Interpolation of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 3: Barycentric Interpolation with barycentric_interpolate
# Given data points (x, y) representing the population of a city over time
x = np.array([1900, 1910, 1920, 1930, 1940, 1950])
y = np.array([5000, 7000, 9000, 12000, 15000, 18000])

# Generate new data points and perform barycentric interpolation
x_new = np.linspace(1900, 1950, 100)
y_new = spi.barycentric_interpolate(x, y, x_new)

# Plot the interpolated curve
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Barycentric Interpolation')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Barycentric Interpolation of City Population over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 4: 2D Interpolation with interp2d
# Given data points (x, y, z) representing the power of a house over time and resources
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 300, 400, 500, 600])
z = np.array([
    [150, 250, 350, 450, 550, 650],
    [160, 260, 360, 460, 560, 660],
    [170, 270, 370, 470, 570, 670],
    [180, 280, 380, 480, 580, 680],
    [190, 290, 390, 490, 590, 690],
    [200, 300, 400, 500, 600, 700]
])

# Create a 2D interpolation function
interp_2d = spi.interp2d(x, y, z, kind='linear')

# Generate new data points and plot the interpolated surface
x_new = np.linspace(0, 5, 100)
y_new = np.linspace(100, 600, 100)
z_new = interp_2d(x_new, y_new)
X, Y = np.meshgrid(x_new, y_new)
plt.contourf(X, Y, z_new, levels=20, cmap='viridis')
plt.colorbar()
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('2D Linear Interpolation of House Power over Time and Resources')
plt.grid(True)
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_24772\3045549791.py:15: DeprecationWarning: `interp2d` is deprecated!
# `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp_2d = spi.interp2d(x, y, z, kind='linear')
# C:\Users\rvign\AppData\Local\Temp\ipykernel_24772\3045549791.py:20: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
# ...

# %%
# Example 5: Spline Interpolation with InterpolatedUnivariateSpline
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create a spline interpolation function
spline_interp = spi.InterpolatedUnivariateSpline(x, y)

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = spline_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Spline Interpolation')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Spline Interpolation of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 6: Nearest Neighbor Interpolation with interp1d
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create a nearest neighbor interpolation function
nearest_interp = spi.interp1d(x, y, kind='nearest')

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = nearest_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Nearest Neighbor Interpolation')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Nearest Neighbor Interpolation of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 7: Akima Interpolation with Akima1DInterpolator
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create an Akima interpolation function
akima_interp = spi.Akima1DInterpolator(x, y)

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = akima_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Akima Interpolation')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Akima Interpolation of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 8: Spline Interpolation with splrep and splev
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Perform spline interpolation
tck = spi.splrep(x, y)
x_new = np.linspace(0, 5, 100)
y_new = spi.splev(x_new, tck)

# Plot the interpolated curve
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Spline Interpolation')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Spline Interpolation of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 9: Polynomial Interpolation with polyfit and polyval
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Perform polynomial interpolation
coefficients = np.polyfit(x, y, deg=3)
x_new = np.linspace(0, 5, 100)
y_new = np.polyval(coefficients, x_new)

# Plot the interpolated curve
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Polynomial Interpolation')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Polynomial Interpolation of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 10: Clough Tocher Interpolation with CloughTocher2DInterpolator
# Given scattered data points (x, y, z) representing the power of a house over time and resources
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 300, 400, 500, 600])
z = np.array([
    [150, 250, 350, 450, 550, 650],
    [160, 260, 360, 460, 560, 660],
    [170, 270, 370, 470, 570, 670],
    [180, 280, 380, 480, 580, 680],
    [190, 290, 390, 490, 590, 690],
    [200, 300, 400, 500, 600, 700]
])

# Create a Clough Tocher interpolation function
ct_interp = spi.CloughTocher2DInterpolator(points=(x, y), values=z)

# Generate new data points and plot the interpolated surface
x_new = np.linspace(0, 5, 100)
y_new = np.linspace(100, 600, 100)
X, Y = np.meshgrid(x_new, y_new)
z_new = ct_interp((X, Y))
plt.contourf(X, Y, z_new, levels=20, cmap='viridis')
plt.colorbar()
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Clough Tocher Interpolation of House Power over Time and Resources')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# QhullError                                Traceback (most recent call last)
# Cell In[11], line 15
#       5 z = np.array([
#       6     [150, 250, 350, 450, 550, 650],
#       7     [160, 260, 360, 460, 560, 660],
#    (...)
#      11     [200, 300, 400, 500, 600, 700]
#      12 ])
#      14 # Create a Clough Tocher interpolation function
# ---> 15 ct_interp = spi.CloughTocher2DInterpolator(points=(x, y), values=z)
#      17 # Generate new data points and plot the interpolated surface
#      18 x_new = np.linspace(0, 5, 100)
#
# File interpnd.pyx:915, in scipy.interpolate.interpnd.CloughTocher2DInterpolator.__init__()
#
# File _qhull.pyx:1827, in scipy.spatial._qhull.Delaunay.__init__()
#
# File _qhull.pyx:353, in scipy.spatial._qhull._Qhull.__init__()
#
# QhullError: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# ...

# %%
# Example 11: Radial Basis Function Interpolation with Rbf
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create an Rbf interpolation function
rbf_interp = spi.Rbf(x, y, function='linear')

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = rbf_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Rbf Interpolation (Linear)')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Radial Basis Function Interpolation (Linear) of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 12: Radial Basis Function Interpolation with Rbf (Multiquadric)
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create an Rbf interpolation function with a multiquadric kernel
rbf_interp = spi.Rbf(x, y, function='multiquadric')

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = rbf_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Rbf Interpolation (Multiquadric)')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Radial Basis Function Interpolation (Multiquadric) of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 13: Radial Basis Function Interpolation with Rbf (Inverse Multiquadric)
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create an Rbf interpolation function with an inverse multiquadric kernel
rbf_interp = spi.Rbf(x, y, function='inverse_multiquadric')

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = rbf_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Rbf Interpolation (Inverse Multiquadric)')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Radial Basis Function Interpolation (Inverse Multiquadric) of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 14: Radial Basis Function Interpolation with Rbf (Gaussian)
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create an Rbf interpolation function with a Gaussian kernel
rbf_interp = spi.Rbf(x, y, function='gaussian')

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = rbf_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Rbf Interpolation (Gaussian)')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Radial Basis Function Interpolation (Gaussian) of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 15: Radial Basis Function Interpolation with Rbf (Cubic)
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create an Rbf interpolation function with a cubic kernel
rbf_interp = spi.Rbf(x, y, function='cubic')

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = rbf_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Rbf Interpolation (Cubic)')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Radial Basis Function Interpolation (Cubic) of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 16: Radial Basis Function Interpolation with Rbf (Quintic)
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create an Rbf interpolation function with a quintic kernel
rbf_interp = spi.Rbf(x, y, function='quintic')

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = rbf_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Rbf Interpolation (Quintic)')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Radial Basis Function Interpolation (Quintic) of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 17: Radial Basis Function Interpolation with Rbf (Thin Plate Spline)
# Given data points (x, y) representing the power of a house over time
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([100, 200, 400, 600, 800, 1000])

# Create an Rbf interpolation function with a thin plate spline kernel
rbf_interp = spi.Rbf(x, y, function='thin_plate')

# Generate new data points and plot the interpolated curve
x_new = np.linspace(0, 5, 100)
y_new = rbf_interp(x_new)
plt.plot(x, y, 'o', label='Data Points')
plt.plot(x_new, y_new, '-', label='Rbf Interpolation (Thin Plate Spline)')
plt.xlabel('Time')
plt.ylabel('Power')
plt.title('Radial Basis Function Interpolation (Thin Plate Spline) of House Power over Time')
plt.legend()
plt.grid(True)
plt.show()
