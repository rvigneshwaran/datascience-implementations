# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Example 1: Normal Distribution
data_normal = np.random.normal(loc=0, scale=1, size=1000)
plt.hist(data_normal, bins=30, density=True, alpha=0.6, color='blue')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Normal Distribution')
plt.show()

# %%
# Example 2: Exponential Distribution
data_exponential = np.random.exponential(scale=1, size=1000)
plt.hist(data_exponential, bins=30, density=True, alpha=0.6, color='green')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Exponential Distribution')
plt.show()

# %%
# Example 3: Uniform Distribution
data_uniform = np.random.uniform(low=0, high=1, size=1000)
plt.hist(data_uniform, bins=30, density=True, alpha=0.6, color='orange')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Uniform Distribution')
plt.show()

# %%
# Example 4: Bernoulli Distribution
data_bernoulli = np.random.binomial(n=1, p=0.5, size=1000)
plt.hist(data_bernoulli, bins=2, density=True, alpha=0.6, color='red')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Bernoulli Distribution')
plt.show()

# %%
# Example 5: T-Test
data_group1 = np.random.normal(loc=0, scale=1, size=100)
data_group2 = np.random.normal(loc=1, scale=1, size=100)
t_statistic, p_value = stats.ttest_ind(data_group1, data_group2)
print("T-Test:")
print("T-Statistic =", t_statistic)
print("P-Value =", p_value)
# Out:
# T-Test:
# T-Statistic = -6.759272464670452
# P-Value = 1.5168349081379256e-10

# %%
# Example 6: Chi-Square Test
data_observed = np.array([[10, 20, 30], [15, 25, 35]])
chi2_stat, p_value, dof, expected = stats.chi2_contingency(data_observed)
print("Chi-Square Test:")
print("Chi2 Statistic =", chi2_stat)
print("P-Value =", p_value)
print("Degrees of Freedom =", dof)
print("Expected Frequencies:")
print(expected)
# Out:
# Chi-Square Test:
# Chi2 Statistic = 0.27692307692307694
# P-Value = 0.870696738961232
# Degrees of Freedom = 2
# Expected Frequencies:
# [[11.11111111 20.         28.88888889]
#  [13.88888889 25.         36.11111111]]

# %%
# Example 7: Kolmogorov-Smirnov Test
data_sample = np.random.normal(loc=0, scale=1, size=100)
ks_statistic, ks_p_value = stats.kstest(data_sample, 'norm')
print("Kolmogorov-Smirnov Test:")
print("KS Statistic =", ks_statistic)
print("KS P-Value =", ks_p_value)
# Out:
# Kolmogorov-Smirnov Test:
# KS Statistic = 0.103153600191491
# KS P-Value = 0.22190548309321123

# %%
# Example 8: F-Test
data_group1 = np.random.normal(loc=0, scale=1, size=100)
data_group2 = np.random.normal(loc=0, scale=2, size=100)
f_statistic, f_p_value = stats.f_oneway(data_group1, data_group2)
print("F-Test:")
print("F-Statistic =", f_statistic)
print("P-Value =", f_p_value)
# Out:
# F-Test:
# F-Statistic = 0.04367450521628439
# P-Value = 0.8346752136803752

# %%
# Example 9: Mann-Whitney U Test
data_group1 = np.random.normal(loc=0, scale=1, size=100)
data_group2 = np.random.normal(loc=1, scale=1, size=100)
u_statistic, u_p_value = stats.mannwhitneyu(data_group1, data_group2)
print("Mann-Whitney U Test:")
print("U-Statistic =", u_statistic)
print("P-Value =", u_p_value)
# Out:
# Mann-Whitney U Test:
# U-Statistic = 1904.0
# P-Value = 3.923347327287328e-14

# %%
# Example 10: Pearson Correlation Coefficient
data_x = np.random.normal(loc=0, scale=1, size=100)
data_y = np.random.normal(loc=0, scale=1, size=100)
correlation_coefficient, _ = stats.pearsonr(data_x, data_y)
print("Pearson Correlation Coefficient:")
print("Correlation Coefficient =", correlation_coefficient)
# Out:
# Pearson Correlation Coefficient:
# Correlation Coefficient = -0.0813163623005719

# %%
# Example 11: Spearman Rank Correlation Coefficient
data_x = np.random.normal(loc=0, scale=1, size=100)
data_y = np.random.normal(loc=0, scale=1, size=100)
correlation_coefficient, _ = stats.spearmanr(data_x, data_y)
print("Spearman Rank Correlation Coefficient:")
print("Correlation Coefficient =", correlation_coefficient)
# Out:
# Spearman Rank Correlation Coefficient:
# Correlation Coefficient = -0.15012301230123012

# %%
# Example 12: Kendall Rank Correlation Coefficient
data_x = np.random.normal(loc=0, scale=1, size=100)
data_y = np.random.normal(loc=0, scale=1, size=100)
correlation_coefficient, _ = stats.kendalltau(data_x, data_y)
print("Kendall Rank Correlation Coefficient:")
print("Correlation Coefficient =", correlation_coefficient)
# Out:
# Kendall Rank Correlation Coefficient:
# Correlation Coefficient = -0.04323232323232324

# %%
# Example 13: Descriptive Statistics
data = np.random.normal(loc=0, scale=1, size=100)
mean = np.mean(data)
median = np.median(data)
variance = np.var(data)
std_dev = np.std(data)
print("Descriptive Statistics:")
print("Mean =", mean)
print("Median =", median)
print("Variance =", variance)
print("Standard Deviation =", std_dev)
# Out:
# Descriptive Statistics:
# Mean = 0.1889664379121198
# Median = 0.1567222938971765
# Variance = 1.1460188147629518
# Standard Deviation = 1.070522682974514

# %%
# Example 14: Probability Density Function (PDF)
x = np.linspace(-5, 5, 100)
pdf_normal = stats.norm.pdf(x, loc=0, scale=1)
plt.plot(x, pdf_normal, label='Normal')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Probability Density Function (PDF)')
plt.legend()
plt.show()

# %%
# Example 15: Cumulative Distribution Function (CDF)
x = np.linspace(-5, 5, 100)
cdf_normal = stats.norm.cdf(x, loc=0, scale=1)
plt.plot(x, cdf_normal, label='Normal')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Cumulative Distribution Function (CDF)')
plt.legend()
plt.show()

# %%
# Example 16: Percentile
data = np.random.normal(loc=0, scale=1, size=100)
percentile_25 = np.percentile(data, 25)
percentile_75 = np.percentile(data, 75)
print("Percentiles:")
print("25th Percentile =", percentile_25)
print("75th Percentile =", percentile_75)
# Out:
# Percentiles:
# 25th Percentile = -0.28607825028459327
# 75th Percentile = 0.7985868688947693

# %%
# Example 17: Hypothesis Testing - One Sample T-Test
data_sample = np.random.normal(loc=0, scale=1, size=100)
t_statistic, p_value = stats.ttest_1samp(data_sample, popmean=0)
print("One Sample T-Test:")
print("T-Statistic =", t_statistic)
print("P-Value =", p_value)
# Out:
# One Sample T-Test:
# T-Statistic = 0.7496575008926933
# P-Value = 0.45523875751323695

# %%
# Example 18: Hypothesis Testing - Paired T-Test
data_before = np.random.normal(loc=0, scale=1, size=100)
data_after = np.random.normal(loc=1, scale=1, size=100)
t_statistic, p_value = stats.ttest_rel(data_before, data_after)
print("Paired T-Test:")
print("T-Statistic =", t_statistic)
print("P-Value =", p_value)
# Out:
# Paired T-Test:
# T-Statistic = -5.753428281138697
# P-Value = 9.782538600972735e-08

# %%
# Example 19: Hypothesis Testing - Chi-Square Test for Goodness of Fit
data_observed = np.array([30, 20, 50])
expected_frequency = np.array([25, 25, 50])
chi2_stat, p_value = stats.chisquare(data_observed, expected_frequency)
print("Chi-Square Test for Goodness of Fit:")
print("Chi2 Statistic =", chi2_stat)
print("P-Value =", p_value)
# Out:
# Chi-Square Test for Goodness of Fit:
# Chi2 Statistic = 2.0
# P-Value = 0.36787944117144245

# %%
# Example 20: Hypothesis Testing - Chi-Square Test for Independence
data_observed = np.array([[10, 20], [15, 25]])
chi2_stat, p_value, dof, expected = stats.chi2_contingency(data_observed)
print("Chi-Square Test for Independence:")
print("Chi2 Statistic =", chi2_stat)
print("P-Value =", p_value)
print("Degrees of Freedom =", dof)
print("Expected Frequencies:")
print(expected)
# Out:
# Chi-Square Test for Independence:
# Chi2 Statistic = 0.011666666666666653
# P-Value = 0.9139858996305869
# Degrees of Freedom = 1
# Expected Frequencies:
# [[10.71428571 19.28571429]
#  [14.28571429 25.71428571]]
