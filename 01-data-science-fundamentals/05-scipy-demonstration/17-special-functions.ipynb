# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as sp

# %%
# Example 1: Bessel Functions
x = np.linspace(0, 10, 100)
J0 = sp.j0(x)
J1 = sp.j1(x)
J2 = sp.jn(2, x)  # J_n(x) for n=2
plt.plot(x, J0, label='J0(x)')
plt.plot(x, J1, label='J1(x)')
plt.plot(x, J2, label='J2(x)')
plt.xlabel('x')
plt.ylabel('Bessel Functions')
plt.legend()
plt.title('Bessel Functions of the First Kind')
plt.grid(True)
plt.show()

# %%
# Example 2: Modified Bessel Functions
x = np.linspace(0, 10, 100)
I0 = sp.i0(x)
I1 = sp.i1(x)
I2 = sp.iv(2, x)  # I_n(x) for n=2
plt.plot(x, I0, label='I0(x)')
plt.plot(x, I1, label='I1(x)')
plt.plot(x, I2, label='I2(x)')
plt.xlabel('x')
plt.ylabel('Modified Bessel Functions')
plt.legend()
plt.title('Modified Bessel Functions of the First Kind')
plt.grid(True)
plt.show()

# %%
# Example 3: Spherical Bessel Functions
x = np.linspace(0, 10, 100)
j0 = sp.spherical_jn(0, x)  # j_n(x) for n=0
j1 = sp.spherical_jn(1, x)  # j_n(x) for n=1
j2 = sp.spherical_jn(2, x)  # j_n(x) for n=2
plt.plot(x, j0, label='j0(x)')
plt.plot(x, j1, label='j1(x)')
plt.plot(x, j2, label='j2(x)')
plt.xlabel('x')
plt.ylabel('Spherical Bessel Functions')
plt.legend()
plt.title('Spherical Bessel Functions')
plt.grid(True)
plt.show()

# %%
# Example 4: Gamma Function
x = np.linspace(0.1, 5, 100)
gamma_x = sp.gamma(x)
plt.plot(x, gamma_x)
plt.xlabel('x')
plt.ylabel('Gamma Function')
plt.title('Gamma Function')
plt.grid(True)
plt.show()

# %%
# Example 5: Digamma Function
x = np.linspace(0.1, 5, 100)
digamma_x = sp.digamma(x)
plt.plot(x, digamma_x)
plt.xlabel('x')
plt.ylabel('Digamma Function')
plt.title('Digamma Function')
plt.grid(True)
plt.show()

# %%
# Example 6: Erf Function
x = np.linspace(-3, 3, 100)
erf_x = sp.erf(x)
plt.plot(x, erf_x)
plt.xlabel('x')
plt.ylabel('Erf Function')
plt.title('Error Function (Erf)')
plt.grid(True)
plt.show()

# %%
# Example 7: Fresnel Functions
x = np.linspace(0, 5, 100)
s, c = sp.fresnel(x)
plt.plot(x, s, label='S(x)')
plt.plot(x, c, label='C(x)')
plt.xlabel('x')
plt.ylabel('Fresnel Functions')
plt.legend()
plt.title('Fresnel Functions')
plt.grid(True)
plt.show()

# %%
# Example 8: Exponential Integral
x = np.linspace(0.1, 5, 100)
ei_x = sp.expi(x)
plt.plot(x, ei_x)
plt.xlabel('x')
plt.ylabel('Exponential Integral')
plt.title('Exponential Integral')
plt.grid(True)
plt.show()

# %%
# Example 9: Airy Functions
x = np.linspace(-10, 10, 100)
Ai_x, Bi_x = sp.airy(x)
plt.plot(x, Ai_x, label='Ai(x)')
plt.plot(x, Bi_x, label='Bi(x)')
plt.xlabel('x')
plt.ylabel('Airy Functions')
plt.legend()
plt.title('Airy Functions')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Example 9: Airy Functions
#       2 x = np.linspace(-10, 10, 100)
# ----> 3 Ai_x, Bi_x = sp.airy(x)
#       4 plt.plot(x, Ai_x, label='Ai(x)')
#       5 plt.plot(x, Bi_x, label='Bi(x)')
#
# ValueError: too many values to unpack (expected 2)

# %%
# Example 10: Bessel Functions Zeros
n = 0
zeros_J0 = sp.jn_zeros(n, 10)
print(f"Zeros of J0(x) for n={n}: {zeros_J0}")
n = 1
zeros_J1 = sp.jn_zeros(n, 10)
print(f"Zeros of J1(x) for n={n}: {zeros_J1}")
# Out:
# Zeros of J0(x) for n=0: [ 2.40482556  5.52007811  8.65372791 11.79153444 14.93091771 18.07106397
#  21.21163663 24.35247153 27.49347913 30.63460647]
# Zeros of J1(x) for n=1: [ 3.83170597  7.01558667 10.17346814 13.32369194 16.47063005 19.61585851
#  22.76008438 25.90367209 29.04682853 32.18967991]

# %%
# Example 11: Gamma Function Logarithm
x = np.linspace(0.1, 5, 100)
log_gamma_x = sp.loggamma(x)
plt.plot(x, log_gamma_x)
plt.xlabel('x')
plt.ylabel('Log-Gamma Function')
plt.title('Log-Gamma Function')
plt.grid(True)
plt.show()

# %%
# Example 12: Exponential Function
x = np.linspace(-2, 2, 100)
exp_x = sp.expn(2, x)
plt.plot(x, exp_x)
plt.xlabel('x')
plt.ylabel('Exponential Function (expn(2, x))')
plt.title('Exponential Function (expn(2, x))')
plt.grid(True)
plt.show()

# %%
# Example 13: Legendre Polynomials
x = np.linspace(-1, 1, 100)
P0 = sp.legendre(0)(x)
P1 = sp.legendre(1)(x)
P2 = sp.legendre(2)(x)
plt.plot(x, P0, label='P0(x)')
plt.plot(x, P1, label='P1(x)')
plt.plot(x, P2, label='P2(x)')
plt.xlabel('x')
plt.ylabel('Legendre Polynomials')
plt.legend()
plt.title('Legendre Polynomials')
plt.grid(True)
plt.show()

# %%
# Example 14: Hermite Polynomials
x = np.linspace(-4, 4, 100)
H0 = sp.hermite(0)(x)
H1 = sp.hermite(1)(x)
H2 = sp.hermite(2)(x)
plt.plot(x, H0, label='H0(x)')
plt.plot(x, H1, label='H1(x)')
plt.plot(x, H2, label='H2(x)')
plt.xlabel('x')
plt.ylabel('Hermite Polynomials')
plt.legend()
plt.title('Hermite Polynomials')
plt.grid(True)
plt.show()

# %%
# Example 15: Laguerre Polynomials
x = np.linspace(0, 5, 100)
L0 = sp.laguerre(0)(x)
L1 = sp.laguerre(1)(x)
L2 = sp.laguerre(2)(x)
plt.plot(x, L0, label='L0(x)')
plt.plot(x, L1, label='L1(x)')
plt.plot(x, L2, label='L2(x)')
plt.xlabel('x')
plt.ylabel('Laguerre Polynomials')
plt.legend()
plt.title('Laguerre Polynomials')
plt.grid(True)
plt.show()

# %%
# Example 16: Sinc Function
x = np.linspace(-10, 10, 100)
sinc_x = sp.sinc(x)
plt.plot(x, sinc_x)
plt.xlabel('x')
plt.ylabel('Sinc Function')
plt.title('Sinc Function')
plt.grid(True)
plt.show()

# %%
# Example 17: Beta Function
x = np.linspace(0.1, 5, 100)
y = np.linspace(0.1, 5, 100)
X, Y = np.meshgrid(x, y)
beta_xy = sp.beta(X, Y)
plt.contourf(X, Y, beta_xy, levels=20, cmap='viridis')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Beta Function')
plt.grid(True)
plt.show()

# %%
# Example 18: Exponential Integral En
x = np.linspace(0.1, 5, 100)
en_x = sp.expn(3, x)
plt.plot(x, en_x)
plt.xlabel('x')
plt.ylabel('Exponential Integral En')
plt.title('Exponential Integral En')
plt.grid(True)
plt.show()

# %%
# Example 19: Fresnel Cosine and Sine Integrals
x = np.linspace(0, 5, 100)
Fresnel_C, Fresnel_S = sp.fresnelc(x), sp.fresnels(x)
plt.plot(x, Fresnel_C, label='Fresnel_C(x)')
plt.plot(x, Fresnel_S, label='Fresnel_S(x)')
plt.xlabel('x')
plt.ylabel('Fresnel Cosine and Sine Integrals')
plt.legend()
plt.title('Fresnel Cosine and Sine Integrals')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Example 19: Fresnel Cosine and Sine Integrals
#       2 x = np.linspace(0, 5, 100)
# ----> 3 Fresnel_C, Fresnel_S = sp.fresnelc(x), sp.fresnels(x)
#       4 plt.plot(x, Fresnel_C, label='Fresnel_C(x)')
#       5 plt.plot(x, Fresnel_S, label='Fresnel_S(x)')
#
# AttributeError: module 'scipy.special' has no attribute 'fresnelc'

# %%
# Example 20: Incomplete Gamma Function
x = np.linspace(0.1, 5, 100)
ig_x = sp.gammainc(2, x)
plt.plot(x, ig_x)
plt.xlabel('x')
plt.ylabel('Incomplete Gamma Function (gammainc(2, x))')
plt.title('Incomplete Gamma Function (gammainc(2, x))')
plt.grid(True)
plt.show()

# %%
# Example 21: Incomplete Beta Function
x = np.linspace(0.1, 5, 100)
ib_x = sp.betainc(2, 3, x)
plt.plot(x, ib_x)
plt.xlabel('x')
plt.ylabel('Incomplete Beta Function (betainc(2, 3, x))')
plt.title('Incomplete Beta Function (betainc(2, 3, x))')
plt.grid(True)
plt.show()

# %%
# Example 22: Hypergeometric Function
x = np.linspace(0.1, 5, 100)
hg_x = sp.hyp1f1(1, 1, x)
plt.plot(x, hg_x)
plt.xlabel('x')
plt.ylabel('Hypergeometric Function (hyp1f1(1, 1, x))')
plt.title('Hypergeometric Function (hyp1f1(1, 1, x))')
plt.grid(True)
plt.show()

# %%
# Example 23: Lambert W Function
x = np.linspace(-1, 10, 100)
w_x = sp.lambertw(x)
plt.plot(x, w_x)
plt.xlabel('x')
plt.ylabel('Lambert W Function')
plt.title('Lambert W Function')
plt.grid(True)
plt.show()
# Out:
# c:\Program Files\Python311\Lib\site-packages\matplotlib\cbook\__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
# Example 24: Riemann Zeta Function
x = np.linspace(0.1, 5, 100)
zeta_x = sp.zeta(x)
plt.plot(x, zeta_x)
plt.xlabel('x')
plt.ylabel('Riemann Zeta Function')
plt.title('Riemann Zeta Function')
plt.grid(True)
plt.show()

# %%
# Example 25: Error Function (Complementary)
x = np.linspace(-3, 3, 100)
erfc_x = sp.erfc(x)
plt.plot(x, erfc_x)
plt.xlabel('x')
plt.ylabel('Complementary Error Function (erfc)')
plt.title('Complementary Error Function (erfc)')
plt.grid(True)
plt.show()

# %%
# Example 26: Error Function (Inverse)
x = np.linspace(-1, 1, 100)
erfinv_x = sp.erfinv(x)
plt.plot(x, erfinv_x)
plt.xlabel('x')
plt.ylabel('Inverse Error Function (erfinv)')
plt.title('Inverse Error Function (erfinv)')
plt.grid(True)
plt.show()

# %%
# Example 27: Error Function (Complex)
x = np.linspace(-3, 3, 100)
erf_complex_x = sp.erf(1j * x)
plt.plot(x, erf_complex_x.real, label='Real Part')
plt.plot(x, erf_complex_x.imag, label='Imaginary Part')
plt.xlabel('x')
plt.ylabel('Error Function (Complex)')
plt.legend()
plt.title('Error Function (Complex)')
plt.grid(True)
plt.show()

# %%
# Example 28: Error Function (Scaled)
x = np.linspace(-3, 3, 100)
scaled_erf_x = sp.erf(x / 2)
plt.plot(x, scaled_erf_x)
plt.xlabel('x')
plt.ylabel('Error Function (Scaled)')
plt.title('Error Function (Scaled)')
plt.grid(True)
plt.show()
