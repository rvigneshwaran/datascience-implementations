# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

# %%
# Example 1: Loading and Displaying an Image
image = plt.imread('example_image.jpg')
plt.imshow(image)
plt.axis('off')
plt.title('Original Image')
plt.show()

# %%
# Example 2: Convert Image to Grayscale
image_gray = np.dot(image[...,:3], [0.2989, 0.5870, 0.1140])
plt.imshow(image_gray, cmap='gray')
plt.axis('off')
plt.title('Grayscale Image')
plt.show()

# %%
# Example 3: Image Flipping
image_flipped = np.flipud(image)
plt.imshow(image_flipped)
plt.axis('off')
plt.title('Flipped Image')
plt.show()

# %%
# Example 4: Image Rotation
image_rotated = ndimage.rotate(image, angle=45, reshape=False)
plt.imshow(image_rotated)
plt.axis('off')
plt.title('Rotated Image')
plt.show()

# %%
# Example 5: Image Resizing
image_resized = ndimage.zoom(image, zoom=0.5)
plt.imshow(image_resized)
plt.axis('off')
plt.title('Resized Image')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Example 5: Image Resizing
#       2 image_resized = ndimage.zoom(image, zoom=0.5)
# ----> 3 plt.imshow(image_resized)
#       4 plt.axis('off')
#       5 plt.title('Resized Image')
#
# File c:\Program Files\Python311\Lib\site-packages\matplotlib\pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2692         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# ...
