# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
# Example 1: Creating a Sine Wave Signal
t = np.linspace(0, 1, 1000)
freq = 5
amplitude = 2
sine_wave = amplitude * np.sin(2 * np.pi * freq * t)
plt.plot(t, sine_wave)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Sine Wave Signal')
plt.grid(True)
plt.show()

# %%
# Example 2: Creating a Square Wave Signal
square_wave = signal.square(2 * np.pi * freq * t)
plt.plot(t, square_wave)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Square Wave Signal')
plt.grid(True)
plt.show()

# %%
# Example 3: Creating a Sawtooth Wave Signal
sawtooth_wave = signal.sawtooth(2 * np.pi * freq * t)
plt.plot(t, sawtooth_wave)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Sawtooth Wave Signal')
plt.grid(True)
plt.show()

# %%
# Example 4: Designing a Low-pass Butterworth Filter
b, a = signal.butter(4, 0.2, 'low')
t = np.linspace(0, 1, 1000)
x = np.sin(2 * np.pi * 5 * t) + 0.5 * np.random.randn(len(t))
filtered_x = signal.lfilter(b, a, x)
plt.plot(t, x, label='Original Signal')
plt.plot(t, filtered_x, label='Filtered Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Low-pass Butterworth Filter')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 5: Designing a High-pass Butterworth Filter
b, a = signal.butter(4, 0.2, 'high')
t = np.linspace(0, 1, 1000)
x = np.sin(2 * np.pi * 5 * t) + 0.5 * np.random.randn(len(t))
filtered_x = signal.lfilter(b, a, x)
plt.plot(t, x, label='Original Signal')
plt.plot(t, filtered_x, label='Filtered Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('High-pass Butterworth Filter')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 6: Designing a Band-pass Butterworth Filter
b, a = signal.butter(4, [0.2, 0.8], 'band')
t = np.linspace(0, 1, 1000)
x = np.sin(2 * np.pi * 5 * t) + 0.5 * np.random.randn(len(t))
filtered_x = signal.lfilter(b, a, x)
plt.plot(t, x, label='Original Signal')
plt.plot(t, filtered_x, label='Filtered Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Band-pass Butterworth Filter')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 7: Designing a Band-stop Butterworth Filter
b, a = signal.butter(4, [0.2, 0.8], 'bandstop')
t = np.linspace(0, 1, 1000)
x = np.sin(2 * np.pi * 5 * t) + 0.5 * np.random.randn(len(t))
filtered_x = signal.lfilter(b, a, x)
plt.plot(t, x, label='Original Signal')
plt.plot(t, filtered_x, label='Filtered Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Band-stop Butterworth Filter')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 8: Calculating the Power Spectral Density (PSD) of a Signal
t = np.linspace(0, 1, 1000)
x = np.sin(2 * np.pi * 5 * t) + 0.5 * np.random.randn(len(t))
frequencies, psd = signal.welch(x)
plt.semilogy(frequencies, psd)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power/Frequency (dB/Hz)')
plt.title('Power Spectral Density (PSD)')
plt.grid(True)
plt.show()

# %%
# Example 9: Applying a Hann Window to a Signal
t = np.linspace(0, 1, 1000)
x = np.sin(2 * np.pi * 5 * t)
windowed_x = signal.hann(len(x)) * x
plt.plot(t, x, label='Original Signal')
plt.plot(t, windowed_x, label='Windowed Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Hann Window')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_5824\2538105551.py:4: DeprecationWarning: Importing hann from 'scipy.signal' is deprecated and will raise an error in SciPy 1.13.0. Please use 'scipy.signal.windows.hann' or the convenience function 'scipy.signal.get_window' instead.
#   windowed_x = signal.hann(len(x)) * x

# %%
# Example 10: Applying a Hamming Window to a Signal
t = np.linspace(0, 1, 1000)
x = np.sin(2 * np.pi * 5 * t)
windowed_x = signal.hamming(len(x)) * x
plt.plot(t, x, label='Original Signal')
plt.plot(t, windowed_x, label='Windowed Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Hamming Window')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_5824\1444754623.py:4: DeprecationWarning: Importing hamming from 'scipy.signal' is deprecated and will raise an error in SciPy 1.13.0. Please use 'scipy.signal.windows.hamming' or the convenience function 'scipy.signal.get_window' instead.
#   windowed_x = signal.hamming(len(x)) * x
