# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.spatial as sps

# %%
# Example 1: Nearest Neighbor Search
points = np.array([[1, 2], [3, 4], [5, 6], [7, 8]])
query_point = np.array([0, 0])

# Create a KDTree data structure
kdtree = sps.KDTree(points)

# Find the nearest neighbor to the query point
nearest_neighbor_dist, nearest_neighbor_idx = kdtree.query(query_point)

# Plot the points and the query point
plt.scatter(points[:, 0], points[:, 1], label='Points')
plt.scatter(query_point[0], query_point[1], color='red', label='Query Point')
plt.scatter(points[nearest_neighbor_idx, 0], points[nearest_neighbor_idx, 1], color='green', label='Nearest Neighbor')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Nearest Neighbor Search')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 2: Nearest Neighbor Search with Multiple Query Points
query_points = np.array([[1, 1], [4, 5], [6, 7]])

# Find the nearest neighbors to the query points
nearest_neighbor_dists, nearest_neighbor_indices = kdtree.query(query_points, k=2)

# Plot the points and the query points
plt.scatter(points[:, 0], points[:, 1], label='Points')
plt.scatter(query_points[:, 0], query_points[:, 1], color='red', label='Query Points')
plt.scatter(points[nearest_neighbor_indices[:, 0], 0], points[nearest_neighbor_indices[:, 0], 1], color='green', label='Nearest Neighbor 1')
plt.scatter(points[nearest_neighbor_indices[:, 1], 0], points[nearest_neighbor_indices[:, 1], 1], color='blue', label='Nearest Neighbor 2')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Nearest Neighbor Search with Multiple Query Points')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 3: Delaunay Triangulation
points = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

# Create a Delaunay triangulation
tri = sps.Delaunay(points)

# Plot the triangulation
plt.triplot(points[:, 0], points[:, 1], tri.simplices)
plt.scatter(points[:, 0], points[:, 1], color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Delaunay Triangulation')
plt.grid(True)
plt.show()

# %%
# Example 4: Convex Hull
points = np.array([[1, 1], [2, 2], [2, 3], [3, 2], [1, 5], [4, 2]])

# Compute the convex hull
hull = sps.ConvexHull(points)

# Plot the points and the convex hull
plt.plot(points[:, 0], points[:, 1], 'o')
for simplex in hull.simplices:
    plt.plot(points[simplex, 0], points[simplex, 1], 'k-')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Convex Hull')
plt.grid(True)
plt.show()

# %%
# Example 5: Voronoi Diagram
points = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

# Create a Voronoi diagram
vor = sps.Voronoi(points)

# Plot the Voronoi diagram
sps.voronoi_plot_2d(vor)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Voronoi Diagram')
plt.grid(True)
plt.show()

# %%
# Example 6: Nearest Neighbor Clustering
points = np.random.rand(20, 2)  # Random points

# Create a KDTree data structure
kdtree = sps.KDTree(points)

# Perform nearest neighbor clustering with a maximum distance threshold
max_distance = 0.3
clusters = kdtree.query_ball_point(points, max_distance)

# Plot the points and the clusters
for cluster_indices in clusters:
    cluster_points = points[cluster_indices]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Nearest Neighbor Clustering')
plt.grid(True)
plt.show()

# %%
# Example 7: K-Means Clustering
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Generate sample data
data, _ = make_blobs(n_samples=300, centers=4, random_state=42)

# Perform K-Means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(data)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_

# Plot the clustered data and centroids
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', color='red', s=100, label='Centroids')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-Means Clustering')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\rvign\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Example 8: Agglomerative Clustering
from sklearn.datasets import make_moons
from sklearn.cluster import AgglomerativeClustering

# Generate sample data
data, _ = make_moons(n_samples=200, noise=0.05, random_state=42)

# Perform Agglomerative clustering
agg_clustering = AgglomerativeClustering(n_clusters=2)
agg_clustering.fit(data)
labels = agg_clustering.labels_

# Plot the clustered data
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Agglomerative Clustering')
plt.grid(True)
plt.show()

# %%
# Example 9: DBSCAN Clustering
from sklearn.datasets import make_circles
from sklearn.cluster import DBSCAN

# Generate sample data
data, _ = make_circles(n_samples=500, noise=0.05, random_state=42)

# Perform DBSCAN clustering
dbscan = DBSCAN(eps=0.1, min_samples=5)
labels = dbscan.fit_predict(data)

# Plot the clustered data
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('DBSCAN Clustering')
plt.grid(True)
plt.show()

# %%
# Example 10: Single-Linkage Clustering
points = np.random.rand(20, 2)  # Random points

# Perform single-linkage clustering
single_linkage = sps.linkage(points, method='single')
dendrogram = sps.dendrogram(single_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Single-Linkage Clustering Dendrogram')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 5
#       2 points = np.random.rand(20, 2)  # Random points
#       4 # Perform single-linkage clustering
# ----> 5 single_linkage = sps.linkage(points, method='single')
#       6 dendrogram = sps.dendrogram(single_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 11: Complete-Linkage Clustering
points = np.random.rand(20, 2)  # Random points

# Perform complete-linkage clustering
complete_linkage = sps.linkage(points, method='complete')
dendrogram = sps.dendrogram(complete_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Complete-Linkage Clustering Dendrogram')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 5
#       2 points = np.random.rand(20, 2)  # Random points
#       4 # Perform complete-linkage clustering
# ----> 5 complete_linkage = sps.linkage(points, method='complete')
#       6 dendrogram = sps.dendrogram(complete_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 12: Average-Linkage Clustering
points = np.random.rand(20, 2)  # Random points

# Perform average-linkage clustering
average_linkage = sps.linkage(points, method='average')
dendrogram = sps.dendrogram(average_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Average-Linkage Clustering Dendrogram')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 5
#       2 points = np.random.rand(20, 2)  # Random points
#       4 # Perform average-linkage clustering
# ----> 5 average_linkage = sps.linkage(points, method='average')
#       6 dendrogram = sps.dendrogram(average_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 13: Centroid-Linkage Clustering
points = np.random.rand(20, 2)  # Random points

# Perform centroid-linkage clustering
centroid_linkage = sps.linkage(points, method='centroid')
dendrogram = sps.dendrogram(centroid_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Centroid-Linkage Clustering Dendrogram')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 5
#       2 points = np.random.rand(20, 2)  # Random points
#       4 # Perform centroid-linkage clustering
# ----> 5 centroid_linkage = sps.linkage(points, method='centroid')
#       6 dendrogram = sps.dendrogram(centroid_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 14: Ward-Linkage Clustering
points = np.random.rand(20, 2)  # Random points

# Perform ward-linkage clustering
ward_linkage = sps.linkage(points, method='ward')
dendrogram = sps.dendrogram(ward_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Ward-Linkage Clustering Dendrogram')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 5
#       2 points = np.random.rand(20, 2)  # Random points
#       4 # Perform ward-linkage clustering
# ----> 5 ward_linkage = sps.linkage(points, method='ward')
#       6 dendrogram = sps.dendrogram(ward_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 15: Convex Hulls and Delaunay Triangulation of Random Points
points = np.random.rand(20, 2)  # Random points

# Compute the convex hull
hull = sps.ConvexHull(points)

# Create a Delaunay triangulation
tri = sps.Delaunay(points)

# Plot the points, the convex hull, and the triangulation
plt.plot(points[:, 0], points[:, 1], 'o')
for simplex in hull.simplices:
    plt.plot(points[simplex, 0], points[simplex, 1], 'k-')
plt.triplot(points[:, 0], points[:, 1], tri.simplices)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Convex Hull and Delaunay Triangulation')
plt.grid(True)
plt.show()

# %%
# Example 16: Voronoi Diagram of Random Points
points = np.random.rand(20, 2)  # Random points

# Create a Voronoi diagram
vor = sps.Voronoi(points)

# Plot the Voronoi diagram
sps.voronoi_plot_2d(vor)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Voronoi Diagram')
plt.grid(True)
plt.show()

# %%
# Example 17: KDTree Nearest Neighbor Search
points = np.random.rand(20, 2)  # Random points

# Create a KDTree data structure
kdtree = sps.KDTree(points)

# Perform nearest neighbor search
query_point = np.array([0.5, 0.5])
nearest_neighbor_dist, nearest_neighbor_idx = kdtree.query(query_point)

# Plot the points and the query point
plt.scatter(points[:, 0], points[:, 1], label='Points')
plt.scatter(query_point[0], query_point[1], color='red', label='Query Point')
plt.scatter(points[nearest_neighbor_idx, 0], points[nearest_neighbor_idx, 1], color='green', label='Nearest Neighbor')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('KDTree Nearest Neighbor Search')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 18: KDTree Nearest Neighbor Search with Multiple Query Points
query_points = np.random.rand(5, 2)  # Random query points

# Perform nearest neighbor search with multiple query points
nearest_neighbor_dists, nearest_neighbor_indices = kdtree.query(query_points)

# Plot the points and the query points
plt.scatter(points[:, 0], points[:, 1], label='Points')
plt.scatter(query_points[:, 0], query_points[:, 1], color='red', label='Query Points')
for i, query_point in enumerate(query_points):
    nearest_neighbor_idx = nearest_neighbor_indices[i]
    plt.scatter(points[nearest_neighbor_idx, 0], points[nearest_neighbor_idx, 1], label=f'Nearest Neighbor {i+1}')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('KDTree Nearest Neighbor Search with Multiple Query Points')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 19: Ball Tree Nearest Neighbor Search
points = np.random.rand(20, 2)  # Random points

# Create a Ball Tree data structure
balltree = sps.BallTree(points)

# Perform nearest neighbor search
query_point = np.array([0.5, 0.5])
nearest_neighbor_dist, nearest_neighbor_idx = balltree.query(query_point)

# Plot the points and the query point
plt.scatter(points[:, 0], points[:, 1], label='Points')
plt.scatter(query_point[0], query_point[1], color='red', label='Query Point')
plt.scatter(points[nearest_neighbor_idx, 0], points[nearest_neighbor_idx, 1], color='green', label='Nearest Neighbor')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Ball Tree Nearest Neighbor Search')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 5
#       2 points = np.random.rand(20, 2)  # Random points
#       4 # Create a Ball Tree data structure
# ----> 5 balltree = sps.BallTree(points)
#       7 # Perform nearest neighbor search
#       8 query_point = np.array([0.5, 0.5])
#
# AttributeError: module 'scipy.spatial' has no attribute 'BallTree'

# %%
# Example 20: Ball Tree Nearest Neighbor Search with Multiple Query Points
query_points = np.random.rand(5, 2)  # Random query points

# Perform nearest neighbor search with multiple query points
nearest_neighbor_dists, nearest_neighbor_indices = balltree.query(query_points)

# Plot the points and the query points
plt.scatter(points[:, 0], points[:, 1], label='Points')
plt.scatter(query_points[:, 0], query_points[:, 1], color='red', label='Query Points')
for i, query_point in enumerate(query_points):
    nearest_neighbor_idx = nearest_neighbor_indices[i]
    plt.scatter(points[nearest_neighbor_idx, 0], points[nearest_neighbor_idx, 1], label=f'Nearest Neighbor {i+1}')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Ball Tree Nearest Neighbor Search with Multiple Query Points')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 5
#       2 query_points = np.random.rand(5, 2)  # Random query points
#       4 # Perform nearest neighbor search with multiple query points
# ----> 5 nearest_neighbor_dists, nearest_neighbor_indices = balltree.query(query_points)
#       7 # Plot the points and the query points
#       8 plt.scatter(points[:, 0], points[:, 1], label='Points')
#
# NameError: name 'balltree' is not defined

# %%
# Example 21: Delaunay Triangulation with Random Points
points = np.random.rand(20, 2)  # Random points

# Create a Delaunay triangulation
tri = sps.Delaunay(points)

# Plot the triangulation
plt.triplot(points[:, 0], points[:, 1], tri.simplices)
plt.scatter(points[:, 0], points[:, 1], color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Delaunay Triangulation with Random Points')
plt.grid(True)
plt.show()

# %%
# Example 22: Convex Hull with Random Points
points = np.random.rand(20, 2)  # Random points

# Compute the convex hull
hull = sps.ConvexHull(points)

# Plot the points and the convex hull
plt.plot(points[:, 0], points[:, 1], 'o')
for simplex in hull.simplices:
    plt.plot(points[simplex, 0], points[simplex, 1], 'k-')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Convex Hull with Random Points')
plt.grid(True)
plt.show()

# %%
# Example 23: Voronoi Diagram with Random Points
points = np.random.rand(20, 2)  # Random points

# Create a Voronoi diagram
vor = sps.Voronoi(points)

# Plot the Voronoi diagram
sps.voronoi_plot_2d(vor)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Voronoi Diagram with Random Points')
plt.grid(True)
plt.show()

# %%
# Example 24: Nearest Neighbor Clustering with Random Points
points = np.random.rand(20, 2)  # Random points

# Create a KDTree data structure
kdtree = sps.KDTree(points)

# Perform nearest neighbor clustering with a maximum distance threshold
max_distance = 0.3
clusters = kdtree.query_ball_point(points, max_distance)

# Plot the points and the clusters
for cluster_indices in clusters:
    cluster_points = points[cluster_indices]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Nearest Neighbor Clustering with Random Points')
plt.grid(True)
plt.show()

# %%
# Example 25: K-Means Clustering with Random Data
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Generate sample data
data, _ = make_blobs(n_samples=300, centers=4, random_state=42)

# Perform K-Means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(data)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_

# Plot the clustered data and centroids
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', color='red', s=100, label='Centroids')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-Means Clustering with Random Data')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\rvign\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Example 26: Agglomerative Clustering with Random Data
from sklearn.datasets import make_moons
from sklearn.cluster import AgglomerativeClustering

# Generate sample data
data, _ = make_moons(n_samples=200, noise=0.05, random_state=42)

# Perform Agglomerative clustering
agg_clustering = AgglomerativeClustering(n_clusters=2)
agg_clustering.fit(data)
labels = agg_clustering.labels_

# Plot the clustered data
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Agglomerative Clustering with Random Data')
plt.grid(True)
plt.show()

# %%
# Example 27: DBSCAN Clustering with Random Data
from sklearn.datasets import make_circles
from sklearn.cluster import DBSCAN

# Generate sample data
data, _ = make_circles(n_samples=500, noise=0.05, random_state=42)

# Perform DBSCAN clustering
dbscan = DBSCAN(eps=0.1, min_samples=5)
labels = dbscan.fit_predict(data)

# Plot the clustered data
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('DBSCAN Clustering with Random Data')
plt.grid(True)
plt.show()

# %%
# Example 28: Single-Linkage Clustering with Random Points
points = np.random.rand(20, 2)  # Random points

# Perform single-linkage clustering
single_linkage = sps.linkage(points, method='single')
dendrogram = sps.dendrogram(single_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Single-Linkage Clustering Dendrogram with Random Points')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 5
#       2 points = np.random.rand(20, 2)  # Random points
#       4 # Perform single-linkage clustering
# ----> 5 single_linkage = sps.linkage(points, method='single')
#       6 dendrogram = sps.dendrogram(single_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 29: Complete-Linkage Clustering with Random Points
points = np.random.rand(20, 2)  # Random points

# Perform complete-linkage clustering
complete_linkage = sps.linkage(points, method='complete')
dendrogram = sps.dendrogram(complete_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Complete-Linkage Clustering Dendrogram with Random Points')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 5
#       2 points = np.random.rand(20, 2)  # Random points
#       4 # Perform complete-linkage clustering
# ----> 5 complete_linkage = sps.linkage(points, method='complete')
#       6 dendrogram = sps.dendrogram(complete_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 30: Average-Linkage Clustering with Random Points
points = np.random.rand(20, 2)  # Random points

# Perform average-linkage clustering
average_linkage = sps.linkage(points, method='average')
dendrogram = sps.dendrogram(average_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Average-Linkage Clustering Dendrogram with Random Points')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 5
#       2 points = np.random.rand(20, 2)  # Random points
#       4 # Perform average-linkage clustering
# ----> 5 average_linkage = sps.linkage(points, method='average')
#       6 dendrogram = sps.dendrogram(average_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 31: Centroid-Linkage Clustering with Random Points
points = np.random.rand(20, 2)  # Random points

# Perform centroid-linkage clustering
centroid_linkage = sps.linkage(points, method='centroid')
dendrogram = sps.dendrogram(centroid_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Centroid-Linkage Clustering Dendrogram with Random Points')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 5
#       2 points = np.random.rand(20, 2)  # Random points
#       4 # Perform centroid-linkage clustering
# ----> 5 centroid_linkage = sps.linkage(points, method='centroid')
#       6 dendrogram = sps.dendrogram(centroid_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 32: Ward-Linkage Clustering with Random Points
points = np.random.rand(20, 2)  # Random points

# Perform ward-linkage clustering
ward_linkage = sps.linkage(points, method='ward')
dendrogram = sps.dendrogram(ward_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Ward-Linkage Clustering Dendrogram with Random Points')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 5
#       2 points = np.random.rand(20, 2)  # Random points
#       4 # Perform ward-linkage clustering
# ----> 5 ward_linkage = sps.linkage(points, method='ward')
#       6 dendrogram = sps.dendrogram(ward_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 33: Nearest Neighbor Clustering with Random Points (Higher Dimension)
points = np.random.rand(20, 3)  # Random points in 3D

# Create a KDTree data structure
kdtree = sps.KDTree(points)

# Perform nearest neighbor clustering with a maximum distance threshold
max_distance = 0.3
clusters = kdtree.query_ball_point(points, max_distance)
# Plot the points and the clusters in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for cluster_indices in clusters:
    cluster_points = points[cluster_indices]
    ax.scatter(cluster_points[:, 0], cluster_points[:, 1], cluster_points[:, 2])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Nearest Neighbor Clustering with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()

# %%
# Example 34: Ball Tree Nearest Neighbor Search with Random Points (Higher Dimension)
points = np.random.rand(20, 3)  # Random points in 3D

# Create a Ball Tree data structure
balltree = sps.BallTree(points)

# Perform nearest neighbor search with a random query point in 3D
query_point = np.random.rand(3)
nearest_neighbor_dist, nearest_neighbor_idx = balltree.query(query_point)

# Plot the points and the query point in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(points[:, 0], points[:, 1], points[:, 2], label='Points')
ax.scatter(query_point[0], query_point[1], query_point[2], color='red', label='Query Point')
ax.scatter(points[nearest_neighbor_idx, 0], points[nearest_neighbor_idx, 1], points[nearest_neighbor_idx, 2], color='green', label='Nearest Neighbor')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Ball Tree Nearest Neighbor Search with Random Points (Higher Dimension)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 5
#       2 points = np.random.rand(20, 3)  # Random points in 3D
#       4 # Create a Ball Tree data structure
# ----> 5 balltree = sps.BallTree(points)
#       7 # Perform nearest neighbor search with a random query point in 3D
#       8 query_point = np.random.rand(3)
#
# AttributeError: module 'scipy.spatial' has no attribute 'BallTree'

# %%
# Example 35: Delaunay Triangulation with Random Points (Higher Dimension)
points = np.random.rand(20, 3)  # Random points in 3D

# Create a Delaunay triangulation
tri = sps.Delaunay(points)

# Plot the triangulation in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(points[:, 0], points[:, 1], points[:, 2], triangles=tri.simplices)
ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='red')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Delaunay Triangulation with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()

# %%
# Example 36: Convex Hull with Random Points (Higher Dimension)
points = np.random.rand(20, 3)  # Random points in 3D

# Compute the convex hull
hull = sps.ConvexHull(points)

# Plot the points and the convex hull in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(points[:, 0], points[:, 1], points[:, 2], triangles=hull.simplices)
ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='red')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Convex Hull with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()

# %%
# Example 37: Voronoi Diagram with Random Points (Higher Dimension)
points = np.random.rand(20, 3)  # Random points in 3D

# Create a Voronoi diagram
vor = sps.Voronoi(points)

# Plot the Voronoi diagram in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
sps.voronoi_plot_2d(vor, ax=ax)
ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='red')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Voronoi Diagram with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 10
#       8 fig = plt.figure()
#       9 ax = fig.add_subplot(111, projection='3d')
# ---> 10 sps.voronoi_plot_2d(vor, ax=ax)
#      11 ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='red')
#      12 ax.set_xlabel('X')
#
# File <decorator-gen-10>:2, in voronoi_plot_2d(vor, ax, **kw)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\spatial\_plotutils.py:20, in _held_figure(func, obj, ax, **kw)
#      18 was_held = getattr(ax, 'ishold', lambda: True)()
#      19 if was_held:
# ---> 20     return func(obj, ax=ax, **kw)
#      21 try:
#      22     ax.hold(True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\spatial\_plotutils.py:220, in voronoi_plot_2d(vor, ax, **kw)
#     217 from matplotlib.collections import LineCollection
#     219 if vor.points.shape[1] != 2:
# ...

# %%
# Example 38: KDTree Nearest Neighbor Search with Random Points (Higher Dimension)
points = np.random.rand(20, 3)  # Random points in 3D

# Create a KDTree data structure
kdtree = sps.KDTree(points)

# Perform nearest neighbor search with a random query point in 3D
query_point = np.random.rand(3)
nearest_neighbor_dist, nearest_neighbor_idx = kdtree.query(query_point)

# Plot the points and the query point in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(points[:, 0], points[:, 1], points[:, 2], label='Points')
ax.scatter(query_point[0], query_point[1], query_point[2], color='red', label='Query Point')
ax.scatter(points[nearest_neighbor_idx, 0], points[nearest_neighbor_idx, 1], points[nearest_neighbor_idx, 2], color='green', label='Nearest Neighbor')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('KDTree Nearest Neighbor Search with Random Points (Higher Dimension)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example 39: Ball Tree Nearest Neighbor Search with Random Points (Higher Dimension)
points = np.random.rand(20, 3)  # Random points in 3D

# Create a Ball Tree data structure
balltree = sps.BallTree(points)

# Perform nearest neighbor search with a random query point in 3D
query_point = np.random.rand(3)
nearest_neighbor_dist, nearest_neighbor_idx = balltree.query(query_point)

# Plot the points and the query point in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(points[:, 0], points[:, 1], points[:, 2], label='Points')
ax.scatter(query_point[0], query_point[1], query_point[2], color='red', label='Query Point')
ax.scatter(points[nearest_neighbor_idx, 0], points[nearest_neighbor_idx, 1], points[nearest_neighbor_idx, 2], color='green', label='Nearest Neighbor')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Ball Tree Nearest Neighbor Search with Random Points (Higher Dimension)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 5
#       2 points = np.random.rand(20, 3)  # Random points in 3D
#       4 # Create a Ball Tree data structure
# ----> 5 balltree = sps.BallTree(points)
#       7 # Perform nearest neighbor search with a random query point in 3D
#       8 query_point = np.random.rand(3)
#
# AttributeError: module 'scipy.spatial' has no attribute 'BallTree'

# %%
# Example 40: Delaunay Triangulation with Random Points (Higher Dimension)
points = np.random.rand(20, 3)  # Random points in 3D

# Create a Delaunay triangulation
tri = sps.Delaunay(points)

# Plot the triangulation in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(points[:, 0], points[:, 1], points[:, 2], triangles=tri.simplices)
ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='red')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Delaunay Triangulation with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()

# %%
# Example 41: Convex Hull with Random Points (Higher Dimension)
points = np.random.rand(20, 3)  # Random points in 3D

# Compute the convex hull
hull = sps.ConvexHull(points)

# Plot the points and the convex hull in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(points[:, 0], points[:, 1], points[:, 2], triangles=hull.simplices)
ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='red')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Convex Hull with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()

# %%
# Example 42: Voronoi Diagram with Random Points (Higher Dimension)
points = np.random.rand(20, 3)  # Random points in 3D

# Create a Voronoi diagram
vor = sps.Voronoi(points)

# Plot the Voronoi diagram in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
sps.voronoi_plot_2d(vor, ax=ax)
ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='red')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Voronoi Diagram with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 10
#       8 fig = plt.figure()
#       9 ax = fig.add_subplot(111, projection='3d')
# ---> 10 sps.voronoi_plot_2d(vor, ax=ax)
#      11 ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='red')
#      12 ax.set_xlabel('X')
#
# File <decorator-gen-10>:2, in voronoi_plot_2d(vor, ax, **kw)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\spatial\_plotutils.py:20, in _held_figure(func, obj, ax, **kw)
#      18 was_held = getattr(ax, 'ishold', lambda: True)()
#      19 if was_held:
# ---> 20     return func(obj, ax=ax, **kw)
#      21 try:
#      22     ax.hold(True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\spatial\_plotutils.py:220, in voronoi_plot_2d(vor, ax, **kw)
#     217 from matplotlib.collections import LineCollection
#     219 if vor.points.shape[1] != 2:
# ...

# %%
# Example 43: Nearest Neighbor Clustering with Random Points (Higher Dimension)
points = np.random.rand(20, 3)  # Random points in 3D

# Create a KDTree data structure
kdtree = sps.KDTree(points)

# Perform nearest neighbor clustering with a maximum distance threshold
max_distance = 0.3
clusters = kdtree.query_ball_point(points, max_distance)

# Plot the points and the clusters in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for cluster_indices in clusters:
    cluster_points = points[cluster_indices]
    ax.scatter(cluster_points[:, 0], cluster_points[:, 1], cluster_points[:, 2])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Nearest Neighbor Clustering with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()

# %%
# Example 44: K-Means Clustering with Random Data (Higher Dimension)
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Generate sample data
data, _ = make_blobs(n_samples=300, centers=4, random_state=42, n_features=4)  # Random data in 4D

# Perform K-Means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(data)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_

# Plot the clustered data and centroids in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:, 0], data[:, 1], data[:, 2], c=labels, cmap='viridis')
ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], marker='x', color='red', s=100, label='Centroids')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')
ax.set_title('K-Means Clustering with Random Data (Higher Dimension)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\rvign\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Example 45: Agglomerative Clustering with Random Data (Higher Dimension)
from sklearn.datasets import make_moons
from sklearn.cluster import AgglomerativeClustering

# Generate sample data
data, _ = make_moons(n_samples=200, noise=0.05, random_state=42)

# Perform Agglomerative clustering
agg_clustering = AgglomerativeClustering(n_clusters=2)
agg_clustering.fit(data)
labels = agg_clustering.labels_

# Plot the clustered data in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:, 0], data[:, 1], data[:, 2], c=labels, cmap='viridis')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')
ax.set_title('Agglomerative Clustering with Random Data (Higher Dimension)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[71], line 16
#      14 fig = plt.figure()
#      15 ax = fig.add_subplot(111, projection='3d')
# ---> 16 ax.scatter(data[:, 0], data[:, 1], data[:, 2], c=labels, cmap='viridis')
#      17 ax.set_xlabel('Feature 1')
#      18 ax.set_ylabel('Feature 2')
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
# Example 46: DBSCAN Clustering with Random Data (Higher Dimension)
from sklearn.datasets import make_circles
from sklearn.cluster import DBSCAN

# Generate sample data
data, _ = make_circles(n_samples=500, noise=0.05, random_state=42)

# Perform DBSCAN clustering
dbscan = DBSCAN(eps=0.1, min_samples=5)
labels = dbscan.fit_predict(data)

# Plot the clustered data in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:, 0], data[:, 1], data[:, 2], c=labels, cmap='viridis')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')
ax.set_title('DBSCAN Clustering with Random Data (Higher Dimension)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[72], line 15
#      13 fig = plt.figure()
#      14 ax = fig.add_subplot(111, projection='3d')
# ---> 15 ax.scatter(data[:, 0], data[:, 1], data[:, 2], c=labels, cmap='viridis')
#      16 ax.set_xlabel('Feature 1')
#      17 ax.set_ylabel('Feature 2')
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
# Example 47: Single-Linkage Clustering with Random Points (Higher Dimension)
points = np.random.rand(20, 4)  # Random points in 4D

# Perform single-linkage clustering
single_linkage = sps.linkage(points, method='single')
dendrogram = sps.dendrogram(single_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Single-Linkage Clustering Dendrogram with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 5
#       2 points = np.random.rand(20, 4)  # Random points in 4D
#       4 # Perform single-linkage clustering
# ----> 5 single_linkage = sps.linkage(points, method='single')
#       6 dendrogram = sps.dendrogram(single_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 48: Complete-Linkage Clustering with Random Points (Higher Dimension)
points = np.random.rand(20, 4)  # Random points in 4D

# Perform complete-linkage clustering
complete_linkage = sps.linkage(points, method='complete')
dendrogram = sps.dendrogram(complete_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Complete-Linkage Clustering Dendrogram with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 5
#       2 points = np.random.rand(20, 4)  # Random points in 4D
#       4 # Perform complete-linkage clustering
# ----> 5 complete_linkage = sps.linkage(points, method='complete')
#       6 dendrogram = sps.dendrogram(complete_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 49: Average-Linkage Clustering with Random Points (Higher Dimension)
points = np.random.rand(20, 4)  # Random points in 4D

# Perform average-linkage clustering
average_linkage = sps.linkage(points, method='average')
dendrogram = sps.dendrogram(average_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Average-Linkage Clustering Dendrogram with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 5
#       2 points = np.random.rand(20, 4)  # Random points in 4D
#       4 # Perform average-linkage clustering
# ----> 5 average_linkage = sps.linkage(points, method='average')
#       6 dendrogram = sps.dendrogram(average_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'

# %%
# Example 50: Centroid-Linkage Clustering with Random Points (Higher Dimension)
points = np.random.rand(20, 4)  # Random points in 4D

# Perform centroid-linkage clustering
centroid_linkage = sps.linkage(points, method='centroid')
dendrogram = sps.dendrogram(centroid_linkage)

# Plot the dendrogram
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Centroid-Linkage Clustering Dendrogram with Random Points (Higher Dimension)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 5
#       2 points = np.random.rand(20, 4)  # Random points in 4D
#       4 # Perform centroid-linkage clustering
# ----> 5 centroid_linkage = sps.linkage(points, method='centroid')
#       6 dendrogram = sps.dendrogram(centroid_linkage)
#       8 # Plot the dendrogram
#
# AttributeError: module 'scipy.spatial' has no attribute 'linkage'
