# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = sns.load_dataset("tips")

# %%
# Example 1: Default violinplot
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("Default violinplot")
plt.show()

# %%
# Example 2: Using hue for categorical differentiation
sns.violinplot(data=df, x="day", y="total_bill", hue="sex")
plt.title("violinplot with hue")
plt.show()

# %%
# Example 3: Using order to specify the order of categories
sns.violinplot(data=df, x="day", y="total_bill", order=["Thur", "Fri", "Sat", "Sun"])
plt.title("violinplot with custom category order")
plt.show()

# %%
# Example 4: Using palette to specify the color palette
sns.violinplot(data=df, x="day", y="total_bill", palette="Set2")
plt.title("violinplot with custom color palette")
plt.show()

# %%
# Example 5: Using saturation to adjust color intensity
sns.violinplot(data=df, x="day", y="total_bill", saturation=0.5)
plt.title("violinplot with adjusted color saturation")
plt.show()

# %%
# Example 6: Using split=True to split violins
sns.violinplot(data=df, x="day", y="total_bill", split=True)
plt.title("violinplot with split violins")
plt.show()

# %%
# Example 7: Using scale="count" to scale the width of the violins by the number of observations
sns.violinplot(data=df, x="day", y="total_bill", scale="count")
plt.title("violinplot with scaled violins")
plt.show()

# %%
# Example 8: Using inner="quartile" to plot quartile values inside the violins
sns.violinplot(data=df, x="day", y="total_bill", inner="quartile")
plt.title("violinplot with quartile values")
plt.show()

# %%
# Example 9: Using inner="stick" to plot individual data points inside the violins
sns.violinplot(data=df, x="day", y="total_bill", inner="stick")
plt.title("violinplot with individual data points")
plt.show()

# %%
# Example 10: Using inner="box" to plot a box plot inside the violins
sns.violinplot(data=df, x="day", y="total_bill", inner="box")
plt.title("violinplot with box plot inside")
plt.show()

# %%
# Example 11: Using bw="silverman" to adjust the bandwidth of the kernel density estimate
sns.violinplot(data=df, x="day", y="total_bill", bw="silverman")
plt.title("violinplot with adjusted bandwidth")
plt.show()

# %%
# Example 12: Using cut=0 to extend the violins to the minimum and maximum values
sns.violinplot(data=df, x="day", y="total_bill", cut=0)
plt.title("violinplot with extended violins")
plt.show()

# %%
# Example 13: Using width=0.8 to adjust the width of the violins
sns.violinplot(data=df, x="day", y="total_bill", width=0.8)
plt.title("violinplot with adjusted violin width")
plt.show()

# %%
# Example 14: Using inner=None to remove inner annotations
sns.violinplot(data=df, x="day", y="total_bill", inner=None)
plt.title("violinplot without inner annotations")
plt.show()

# %%
# Example 15: Using outer=True to plot observations outside the violins
sns.violinplot(data=df, x="day", y="total_bill", outer=True)
plt.title("violinplot with observations outside")
plt.show()

# %%
# Example 16: Using scale_hue=True to scale the violins within each hue category
sns.violinplot(data=df, x="day", y="total_bill", hue="sex", scale_hue=True)
plt.title("violinplot with scaled violins within each hue")
plt.show()

# %%
# Example 17: Using scale_hue=False to independently scale the violins within each hue category
sns.violinplot(data=df, x="day", y="total_bill", hue="sex", scale_hue=False)
plt.title("violinplot without scaling violins within each hue")
plt.show()

# %%
# Example 18: Using dodge=True to separate violins for hue categories
sns.violinplot(data=df, x="day", y="total_bill", hue="sex", dodge=True)
plt.title("violinplot with separated violins for hue categories")
plt.show()

# %%
# Example 19: Using split=True and scale_hue=True for split violins within each hue category
sns.violinplot(data=df, x="day", y="total_bill", hue="sex", split=True, scale_hue=True)
plt.title("violinplot with split and scaled violins within each hue")
plt.show()

# %%
# Example 20: Using different plot styles
sns.set(style="whitegrid")
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("violinplot with different plot style")
plt.show()

# %%
# Example 21: Using different plot contexts
sns.set_context("paper")
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("violinplot with different plot context")
plt.show()

# %%
# Example 22: Using different font scales
sns.set(font_scale=1.5)
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("violinplot with different font scale")
plt.show()

# %%
# Example 23: Using different plot themes
sns.set_theme(style="darkgrid")
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("violinplot with different plot theme")
plt.show()

# %%
# Example 24: Using different axis labels
sns.violinplot(data=df, x="day", y="total_bill")
plt.xlabel("Day of Week")
plt.ylabel("Total Bill")
plt.title("violinplot with different axis labels")
plt.show()

# %%
# Example 25: Using different plot titles
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("Custom Plot Title", fontsize=16, fontweight="bold")
plt.show()

# %%
# Example 26: Using different plot size
sns.violinplot(data=df, x="day", y="total_bill", figsize=(8, 6))
plt.title("violinplot with different plot size")
plt.show()

# %%
# Example 27: Using different plot style and context together
sns.set(style="darkgrid", context="poster")
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("violinplot with different plot style and context")
plt.show()

# %%
# Example 1: Using hue_order to specify the order of hue categories
sns.violinplot(data=df, x="day", y="total_bill", hue="sex", hue_order=["Male", "Female"])
plt.title("violinplot with custom hue order")
plt.show()

# %%
# Example 2: Using dodge=True and hue_order to separate violins for hue categories
sns.violinplot(data=df, x="day", y="total_bill", hue="sex", dodge=True, hue_order=["Male", "Female"])
plt.title("violinplot with separated violins for hue categories")
plt.show()

# %%
# Example 3: Using bw_adjust to adjust the bandwidth of the kernel density estimate
sns.violinplot(data=df, x="day", y="total_bill", bw_adjust=0.5)
plt.title("violinplot with adjusted bandwidth")
plt.show()

# %%
# Example 4: Using inner="stick" and split=True to plot individual data points inside split violins
sns.violinplot(data=df, x="day", y="total_bill", inner="stick", split=True)
plt.title("violinplot with split violins and individual data points")
plt.show()

# %%
# Example 5: Using inner="quartile" and split=True to plot quartile values inside split violins
sns.violinplot(data=df, x="day", y="total_bill", inner="quartile", split=True)
plt.title("violinplot with split violins and quartile values")
plt.show()

# %%
# Example 6: Using split=True, scale_hue=True, and scale="width" to scale the width of split violins within each hue category
sns.violinplot(data=df, x="day", y="total_bill", hue="sex", split=True, scale_hue=True, scale="width")
plt.title("violinplot with scaled width for split violins within each hue")
plt.show()

# %%
# Example 7: Using scale="area" to scale the area of the violins
sns.violinplot(data=df, x="day", y="total_bill", scale="area")
plt.title("violinplot with scaled area")
plt.show()

# %%
# Example 8: Using cut=2 to extend the violins to the 2nd and 98th percentiles
sns.violinplot(data=df, x="day", y="total_bill", cut=2)
plt.title("violinplot with extended violins")
plt.show()

# %%
# Example 9: Using scale="count" and scale_hue=True to scale the violins by the number of observations within each hue category
sns.violinplot(data=df, x="day", y="total_bill", hue="sex", scale="count", scale_hue=True)
plt.title("violinplot with scaled violins by count within each hue")
plt.show()

# %%
# Example 10: Using linewidth=2 to adjust the width of the violinplot lines
sns.violinplot(data=df, x="day", y="total_bill", linewidth=2)
plt.title("violinplot with adjusted line width")
plt.show()

# %%
# Example 11: Using inner="box" and split=True to plot a box plot inside split violins
sns.violinplot(data=df, x="day", y="total_bill", inner="box", split=True)
plt.title("violinplot with split violins and box plot inside")
plt.show()

# %%
# Example 12: Using inner="stick" and scale_hue=True to plot individual data points inside scaled violins within each hue category
sns.violinplot(data=df, x="day", y="total_bill", hue="sex", inner="stick", scale_hue=True)
plt.title("violinplot with individual data points inside scaled violins within each hue")
plt.show()

# %%
# Example 13: Using palette="pastel" to specify a custom color palette
sns.violinplot(data=df, x="day", y="total_bill", palette="pastel")
plt.title("violinplot with custom color palette")
plt.show()

# %%
# Example 14: Using linewidths=0.5 to adjust the width of the violinplot lines
sns.violinplot(data=df, x="day", y="total_bill", linewidths=0.5)
plt.title("violinplot with adjusted line widths")
plt.show()

# %%
# Example 15: Using saturation=0.8 to adjust the color saturation of the palette
sns.violinplot(data=df, x="day", y="total_bill", saturation=0.8)
plt.title("violinplot with adjusted color saturation")
plt.show()

# %%
# Example 16: Using edgecolor="black" to specify the color of the violinplot edges
sns.violinplot(data=df, x="day", y="total_bill", edgecolor="black")
plt.title("violinplot with custom edge color")
plt.show()

# %%
# Example 17: Using capsize=0.2 to adjust the size of the caps on the violinplot
sns.violinplot(data=df, x="day", y="total_bill", capsize=0.2)
plt.title("violinplot with adjusted cap size")
plt.show()

# %%
# Example 18: Using width=0.8 and inner="stick" to adjust the width and plot individual data points
sns.violinplot(data=df, x="day", y="total_bill", width=0.8, inner="stick")
plt.title("violinplot with adjusted width and individual data points")
plt.show()

# %%
# Example 19: Using violinprops to customize properties of the violins
sns.violinplot(data=df, x="day", y="total_bill", violinprops={"facecolor": "lightblue", "alpha": 0.5})
plt.title("violinplot with customized violin properties")
plt.show()

# %%
# Example 20: Using scale_hue=False to independently scale the violins within each hue category
sns.violinplot(data=df, x="day", y="total_bill", hue="sex", scale_hue=False)
plt.title("violinplot without scaling violins within each hue")
plt.show()

# %%
# Example 21: Using plot_kws={"linestyle": "--"} to customize the linestyle of the violinplot lines
sns.violinplot(data=df, x="day", y="total_bill", plot_kws={"linestyle": "--"})
plt.title("violinplot with customized linestyle")
plt.show()

# %%
# Example 22: Using inner_kws={"linewidth": 2} to adjust the width of the inner elements
sns.violinplot(data=df, x="day", y="total_bill", inner_kws={"linewidth": 2})
plt.title("violinplot with adjusted inner element width")
plt.show()

# %%
# Example 23: Using scale="width" and inner_kws={"width": 0.6} to adjust the width of the inner elements
sns.violinplot(data=df, x="day", y="total_bill", scale="width", inner_kws={"width": 0.6})
plt.title("violinplot with adjusted inner element width")
plt.show()

# %%
# Example 24: Using violinprops and inner_kws together to customize violin and inner element properties
sns.violinplot(data=df, x="day", y="total_bill", violinprops={"facecolor": "lightblue"}, inner_kws={"linewidth": 2})
plt.title("violinplot with customized violin and inner element properties")
plt.show()

# %%
# Example 25: Using different plot styles
sns.set(style="whitegrid")
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("violinplot with different plot style")
plt.show()
