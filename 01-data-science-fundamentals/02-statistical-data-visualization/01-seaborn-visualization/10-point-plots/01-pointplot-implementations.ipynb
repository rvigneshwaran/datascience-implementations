# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = sns.load_dataset("tips")

# %%
# Example 1: Default pointplot
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Default pointplot")
plt.show()

# %%
# Example 2: Using hue for categorical differentiation
sns.pointplot(data=df, x="day", y="total_bill", hue="sex")
plt.title("pointplot with hue")
plt.show()

# %%
# Example 3: Using order to specify the order of categories
sns.pointplot(data=df, x="day", y="total_bill", order=["Sun", "Sat", "Fri", "Thur"])
plt.title("pointplot with custom category order")
plt.show()

# %%
# Example 4: Using palette to specify the color palette
sns.pointplot(data=df, x="day", y="total_bill", palette="Set2")
plt.title("pointplot with custom color palette")
plt.show()

# %%
# Example 5: Using estimator to aggregate data within each category
sns.pointplot(data=df, x="day", y="total_bill", estimator=sum)
plt.title("pointplot with custom estimator (sum)")
plt.show()

# %%
# Example 6: Using ci to show confidence intervals
sns.pointplot(data=df, x="day", y="total_bill", ci=95)
plt.title("pointplot with confidence intervals (95%)")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_3428\902624.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.pointplot(data=df, x="day", y="total_bill", ci=95)

# %%
# Example 7: Using capsize to adjust the length of the error bars
sns.pointplot(data=df, x="day", y="total_bill", capsize=0.2)
plt.title("pointplot with adjusted error bar length")
plt.show()

# %%
# Example 8: Using join=False to remove the lines connecting the points
sns.pointplot(data=df, x="day", y="total_bill", join=False)
plt.title("pointplot without connecting lines")
plt.show()

# %%
# Example 9: Using dodge=True to separate the points for hue categories
sns.pointplot(data=df, x="day", y="total_bill", hue="sex", dodge=True)
plt.title("pointplot with separated points for hue categories")
plt.show()

# %%
# Example 10: Using markers to customize the appearance of the points
sns.pointplot(data=df, x="day", y="total_bill", markers=["o", "s", "D", "^"])
plt.title("pointplot with customized point markers")
plt.show()

# %%
# Example 11: Using linestyles to customize the appearance of the lines
sns.pointplot(data=df, x="day", y="total_bill", linestyles=["-", "--", ":", "-."])
plt.title("pointplot with customized line styles")
plt.show()

# %%
# Example 12: Using scale to adjust the scale of the plot
sns.pointplot(data=df, x="day", y="total_bill", scale=0.5)
plt.title("pointplot with adjusted scale")
plt.show()

# %%
# Example 13: Using units to represent multiple observations within each category
sns.pointplot(data=df, x="day", y="total_bill", units="size")
plt.title("pointplot with multiple observations represented as units")
plt.show()

# %%
# Example 14: Using estimator=None and markers to represent individual observations
sns.pointplot(data=df, x="day", y="total_bill", estimator=None, markers="o")
plt.title("pointplot with individual observations")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Example 14: Using estimator=None and markers to represent individual observations
# ----> 2 sns.pointplot(data=df, x="day", y="total_bill", estimator=None, markers="o")
#       3 plt.title("pointplot with individual observations")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2839, in pointplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, ci, capsize, label, ax)
#    2829 def pointplot(
#    2830     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2831     estimator="mean", errorbar=("ci", 95), n_boot=1000, units=None, seed=None,
#    (...)
#    2834     capsize=None, label=None, ax=None,
#    2835 ):
# ...

# %%
# Example 15: Using scale_hue to adjust the width of the hue category bars
sns.pointplot(data=df, x="day", y="total_bill", hue="sex", scale_hue=0.8)
plt.title("pointplot with adjusted hue category bar width")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Example 15: Using scale_hue to adjust the width of the hue category bars
# ----> 2 sns.pointplot(data=df, x="day", y="total_bill", hue="sex", scale_hue=0.8)
#       3 plt.title("pointplot with adjusted hue category bar width")
#       4 plt.show()
#
# TypeError: pointplot() got an unexpected keyword argument 'scale_hue'

# %%
# Example 16: Using palette="husl" to specify a custom color palette
sns.pointplot(data=df, x="day", y="total_bill", palette="husl")
plt.title("pointplot with custom color palette")
plt.show()

# %%
# Example 17: Using errwidth to adjust the width of the error bars
sns.pointplot(data=df, x="day", y="total_bill", errwidth=2)
plt.title("pointplot with adjusted error bar width")
plt.show()

# %%
# Example 18: Using capsize=0.1 and errwidth=1 to adjust the length and width of the error bars
sns.pointplot(data=df, x="day", y="total_bill", capsize=0.1, errwidth=1)
plt.title("pointplot with adjusted error bar length and width")
plt.show()

# %%
# Example 19: Using scale="count" to scale the width of the confidence intervals by the square root of the number of observations
sns.pointplot(data=df, x="day", y="total_bill", scale="count")
plt.title("pointplot with scaled confidence intervals")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Example 19: Using scale="count" to scale the width of the confidence intervals by the square root of the number of observations
# ----> 2 sns.pointplot(data=df, x="day", y="total_bill", scale="count")
#       3 plt.title("pointplot with scaled confidence intervals")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2847, in pointplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, ci, capsize, label, ax)
#    2844 if ax is None:
#    2845     ax = plt.gca()
# -> 2847 plotter.plot(ax)
#    2848 return ax
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:1735, in _PointPlotter.plot(self, ax)
#    1733 def plot(self, ax):
# ...

# %%
# Example 20: Using ax to plot multiple pointplots on the same figure
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

sns.pointplot(data=df, x="day", y="total_bill", ax=axes[0, 0])
axes[0, 0].set_title("pointplot 1")

sns.pointplot(data=df, x="day", y="total_bill", ax=axes[0, 1])
axes[0, 1].set_title("pointplot 2")

sns.pointplot(data=df, x="day", y="total_bill", ax=axes[1, 0])
axes[1, 0].set_title("pointplot 3")

sns.pointplot(data=df, x="day", y="total_bill", ax=axes[1, 1])
axes[1, 1].set_title("pointplot 4")

plt.tight_layout()
plt.show()

# %%
# Example 21: Using different plot styles
sns.set(style="whitegrid")
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("pointplot with different plot style")
plt.show()

# %%
# Example 22: Using different plot context
sns.set(context="talk")
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("pointplot with different plot context")
plt.show()

# %%
# Example 23: Using different font scale
sns.set(font_scale=1.5)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("pointplot with different font scale")
plt.show()

# %%
# Example 24: Using different plot theme
sns.set_theme(style="ticks")
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("pointplot with different plot theme")
plt.show()

# %%
# Example 25: Using different figure size
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("pointplot with default figure size")
plt.show()

plt.figure(figsize=(10, 6))
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("pointplot with adjusted figure size")
plt.show()

# %%
# Example 26: Using violinplot and pointplot together
plt.subplot(1, 2, 1)
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("Violinplot")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 27: Using barplot and pointplot together
plt.subplot(1, 2, 1)
sns.barplot(data=df, x="day", y="total_bill")
plt.title("Barplot")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 28: Using boxplot and pointplot together
plt.subplot(1, 2, 1)
sns.boxplot(data=df, x="day", y="total_bill")
plt.title("Boxplot")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 29: Using stripplot and pointplot together
plt.subplot(1, 2, 1)
sns.stripplot(data=df, x="day", y="total_bill")
plt.title("Stripplot")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 30: Using countplot and pointplot together
plt.subplot(1, 2, 1)
sns.countplot(data=df, x="day")
plt.title("Countplot")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 31: Using swarmplot and pointplot together
plt.subplot(1, 2, 1)
sns.swarmplot(data=df, x="day", y="total_bill")
plt.title("Swarmplot")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 32: Using kdeplot and pointplot together
plt.subplot(1, 2, 1)
sns.kdeplot(data=df, x="total_bill")
plt.title("KDEplot")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 33: Using histogram and pointplot together
plt.subplot(1, 2, 1)
plt.hist(df["total_bill"], bins=10)
plt.title("Histogram")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 34: Using swarmplot and violinplot together
plt.subplot(1, 2, 1)
sns.swarmplot(data=df, x="day", y="total_bill")
plt.title("Swarmplot")

plt.subplot(1, 2, 2)
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("Violinplot")
plt.tight_layout()
plt.show()

# %%
# Example 35: Using stripplot and violinplot together
plt.subplot(1, 2, 1)
sns.stripplot(data=df, x="day", y="total_bill")
plt.title("Stripplot")

plt.subplot(1, 2, 2)
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("Violinplot")
plt.tight_layout()
plt.show()

# %%
# Example 36: Using boxplot and violinplot together
plt.subplot(1, 2, 1)
sns.boxplot(data=df, x="day", y="total_bill")
plt.title("Boxplot")

plt.subplot(1, 2, 2)
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("Violinplot")
plt.tight_layout()
plt.show()

# %%
# Example 37: Using stripplot and boxplot together
plt.subplot(1, 2, 1)
sns.stripplot(data=df, x="day", y="total_bill")
plt.title("Stripplot")

plt.subplot(1, 2, 2)
sns.boxplot(data=df, x="day", y="total_bill")
plt.title("Boxplot")
plt.tight_layout()
plt.show()

# %%
# Example 38: Using swarmplot, violinplot, and boxplot together
plt.subplot(1, 3, 1)
sns.swarmplot(data=df, x="day", y="total_bill")
plt.title("Swarmplot")

plt.subplot(1, 3, 2)
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("Violinplot")

plt.subplot(1, 3, 3)
sns.boxplot(data=df, x="day", y="total_bill")
plt.title("Boxplot")
plt.tight_layout()
plt.show()
# Out:
# c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 12.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 12.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Example 39: Using lineplot and pointplot together
plt.subplot(1, 2, 1)
sns.lineplot(data=df, x="day", y="total_bill")
plt.title("Lineplot")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 40: Using scatterplot and pointplot together
plt.subplot(1, 2, 1)
sns.scatterplot(data=df, x="day", y="total_bill")
plt.title("Scatterplot")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 41: Using barplot, lineplot, and pointplot together
plt.subplot(1, 3, 1)
sns.barplot(data=df, x="day", y="total_bill")
plt.title("Barplot")

plt.subplot(1, 3, 2)
sns.lineplot(data=df, x="day", y="total_bill")
plt.title("Lineplot")

plt.subplot(1, 3, 3)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 42: Using boxplot, scatterplot, and pointplot together
plt.subplot(1, 3, 1)
sns.boxplot(data=df, x="day", y="total_bill")
plt.title("Boxplot")

plt.subplot(1, 3, 2)
sns.scatterplot(data=df, x="day", y="total_bill")
plt.title("Scatterplot")

plt.subplot(1, 3, 3)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 43: Using violinplot, lineplot, and pointplot together
plt.subplot(1, 3, 1)
sns.violinplot(data=df, x="day", y="total_bill")
plt.title("Violinplot")

plt.subplot(1, 3, 2)
sns.lineplot(data=df, x="day", y="total_bill")
plt.title("Lineplot")

plt.subplot(1, 3, 3)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 44: Using swarmplot, lineplot, and pointplot together
plt.subplot(1, 3, 1)
sns.swarmplot(data=df, x="day", y="total_bill")
plt.title("Swarmplot")

plt.subplot(1, 3, 2)
sns.lineplot(data=df, x="day", y="total_bill")
plt.title("Lineplot")

plt.subplot(1, 3, 3)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()
# Out:
# c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 12.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Example 45: Using stripplot, lineplot, and pointplot together
plt.subplot(1, 3, 1)
sns.stripplot(data=df, x="day", y="total_bill")
plt.title("Stripplot")

plt.subplot(1, 3, 2)
sns.lineplot(data=df, x="day", y="total_bill")
plt.title("Lineplot")

plt.subplot(1, 3, 3)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 46: Using regplot and pointplot together
plt.subplot(1, 2, 1)
sns.regplot(data=df, x="total_bill", y="tip")
plt.title("Regplot")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()

# %%
# Example 47: Using lmplot and pointplot together
plt.subplot(1, 2, 1)
sns.lmplot(data=df, x="total_bill", y="tip")
plt.title("Lmplot")

plt.subplot(1, 2, 2)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_3428\2155122861.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 2)

# %%
# Example 49: Using lmplot, scatterplot, and pointplot together
plt.subplot(1, 3, 1)
sns.lmplot(data=df, x="total_bill", y="tip")
plt.title("Lmplot")

plt.subplot(1, 3, 2)
sns.scatterplot(data=df, x="total_bill", y="tip")
plt.title("Scatterplot")

plt.subplot(1, 3, 3)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_3428\4103632598.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 3, 2)

# %%
# Example 50: Using regplot, scatterplot, and pointplot together
plt.subplot(1, 3, 1)
sns.regplot(data=df, x="total_bill", y="tip")
plt.title("Regplot")

plt.subplot(1, 3, 2)
sns.scatterplot(data=df, x="total_bill", y="tip")
plt.title("Scatterplot")

plt.subplot(1, 3, 3)
sns.pointplot(data=df, x="day", y="total_bill")
plt.title("Pointplot")
plt.tight_layout()
plt.show()
