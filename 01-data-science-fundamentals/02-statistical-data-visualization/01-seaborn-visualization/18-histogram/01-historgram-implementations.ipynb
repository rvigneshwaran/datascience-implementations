# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load a pre-built dataset from Seaborn
iris = sns.load_dataset("iris")

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# %%
# Example 1: Basic Histogram
sns.histplot(data=iris, x="sepal_length")
plt.title("Basic Histogram")
plt.show()

# %%
# Example 2: Histogram with Custom Number of Bins
sns.histplot(data=iris, x="sepal_length", bins=20)
plt.title("Histogram with Custom Number of Bins")
plt.show()

# %%
# Example 3: Histogram with Specific Color
sns.histplot(data=iris, x="sepal_length", color="skyblue")
plt.title("Histogram with Specific Color")
plt.show()

# %%
# Example 4: Histogram with Edge Color
sns.histplot(data=iris, x="sepal_length", edgecolor="black")
plt.title("Histogram with Edge Color")
plt.show()

# %%
# Example 5: Histogram with Density Plot
sns.histplot(data=iris, x="sepal_length", kde=True)
plt.title("Histogram with Density Plot")
plt.show()

# %%
# Example 6: Histogram with Rug Plot
sns.histplot(data=iris, x="sepal_length", kde=True, rug=True)
plt.title("Histogram with Rug Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Example 6: Histogram with Rug Plot
# ----> 2 sns.histplot(data=iris, x="sepal_length", kde=True, rug=True)
#       3 plt.title("Histogram with Rug Plot")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\distributions.py:1412, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1410     else:
#    1411         method = ax.plot
# -> 1412     color = _default_color(method, hue, color, kwargs)
#    1414 if not p.has_xy_data:
#    1415     return ax
#
# ...

# %%
# Example 7: Histogram with Multiple Columns
sns.histplot(data=iris, x="sepal_length", hue="species")
plt.title("Histogram with Multiple Columns")
plt.show()

# %%
# Example 8: Histogram with Stacked Bars
sns.histplot(data=iris, x="sepal_length", hue="species", multiple="stack")
plt.title("Histogram with Stacked Bars")
plt.show()

# %%
# Example 9: Histogram with Dodge Bars
sns.histplot(data=iris, x="sepal_length", hue="species", multiple="dodge")
plt.title("Histogram with Dodge Bars")
plt.show()

# %%
# Example 10: Histogram with Cumulative Distribution
sns.histplot(data=iris, x="sepal_length", cumulative=True)
plt.title("Histogram with Cumulative Distribution")
plt.show()

# %%
# Example 11: Histogram with Cumulative Density Function
sns.histplot(data=iris, x="sepal_length", cumulative=True, stat="density")
plt.title("Histogram with Cumulative Density Function")
plt.show()

# %%
# Example 12: Histogram with Shaded Area
sns.histplot(data=iris, x="sepal_length", kde=True, kde_kws={"shade": True})
plt.title("Histogram with Shaded Area")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Example 12: Histogram with Shaded Area
# ----> 2 sns.histplot(data=iris, x="sepal_length", kde=True, kde_kws={"shade": True})
#       3 plt.title("Histogram with Shaded Area")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\distributions.py:1432, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421 estimate_kws = dict(
#    1422     stat=stat,
#    1423     bins=bins,
#    (...)
#    1427     cumulative=cumulative,
#    1428 )
#    1430 if p.univariate:
# -> 1432     p.plot_univariate_histogram(
# ...

# %%
# Example 13: Histogram with Log-scaled Axis
sns.histplot(data=iris, x="sepal_length", log_scale=True)
plt.title("Histogram with Log-scaled Axis")
plt.show()

# %%
# Example 14: Histogram with Specific Axis Limits
sns.histplot(data=iris, x="sepal_length")
plt.xlim(4, 8)
plt.title("Histogram with Specific Axis Limits")
plt.show()

# %%
# Example 15: Histogram with Custom Tick Positions
sns.histplot(data=iris, x="sepal_length")
plt.xticks([4, 5, 6, 7, 8])
plt.title("Histogram with Custom Tick Positions")
plt.show()

# %%
# Example 16: Histogram with Custom Tick Labels
sns.histplot(data=iris, x="sepal_length")
plt.xticks([4, 5, 6, 7, 8], labels=["Four", "Five", "Six", "Seven", "Eight"])
plt.title("Histogram with Custom Tick Labels")
plt.show()

# %%
# Example 17: Histogram with Custom X-axis Label
sns.histplot(data=iris, x="sepal_length")
plt.xlabel("Sepal Length (cm)")
plt.title("Histogram with Custom X-axis Label")
plt.show()

# %%
# Example 18: Histogram with Custom Y-axis Label
sns.histplot(data=iris, x="sepal_length")
plt.ylabel("Frequency")
plt.title("Histogram with Custom Y-axis Label")
plt.show()

# %%
# Example 19: Histogram with Custom Title
sns.histplot(data=iris, x="sepal_length")
plt.title("Custom Histogram Title")
plt.show()

# %%
# Example 20: Histogram with Subplot
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.histplot(data=iris, x="sepal_length")
plt.title("Histogram in Subplot 1")
# Out:
# Text(0.5, 1.0, 'Histogram in Subplot 1')

# %%
plt.subplot(1, 2, 2)
sns.histplot(data=iris, x="sepal_width", color="orange")
plt.title("Histogram in Subplot 2")
plt.show()

# %%
# Example 21: Histogram with Despine
sns.histplot(data=iris, x="sepal_length")
sns.despine()
plt.title("Histogram with Despine")
plt.show()

# %%
# Example 22: Histogram with Custom Despine
sns.histplot(data=iris, x="sepal_length")
sns.despine(left=True, bottom=True)
plt.title("Histogram with Custom Despine")
plt.show()

# %%
# Example 23: Histogram with Different Line Style
sns.histplot(data=iris, x="sepal_length", linestyle='dashed')
plt.title("Histogram with Different Line Style")
plt.show()

# %%
# Example 24: Histogram with Alpha (Transparency)
sns.histplot(data=iris, x="sepal_length", alpha=0.5)
plt.title("Histogram with Alpha (Transparency)")
plt.show()

# %%
# Example 25: Histogram with Different Fill Color
sns.histplot(data=iris, x="sepal_length", fill=True, color="lightgreen")
plt.title("Histogram with Different Fill Color")
plt.show()
