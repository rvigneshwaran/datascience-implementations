# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load a pre-built dataset from Seaborn
tips = sns.load_dataset("tips")

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# Example 1: Basic countplot
sns.countplot(data=tips, x='day')
plt.title("Basic Countplot")
plt.show()

# %%
# Example 2: Countplot with hue
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Hue")
plt.show()

# %%
# Example 3: Countplot with custom order
sns.countplot(data=tips, x='day', order=['Sun', 'Sat', 'Thur', 'Fri'])
plt.title("Countplot with Custom Order")
plt.show()

# %%
# Example 4: Countplot with custom palette
sns.countplot(data=tips, x='day', palette='husl')
plt.title("Countplot with Custom Palette")
plt.show()

# %%
# Example 5: Countplot with hue and custom palette
sns.countplot(data=tips, x='day', hue='sex', palette='Set1')
plt.title("Countplot with Hue and Custom Palette")
plt.show()

# %%
# Example 6: Countplot with hue and custom order
sns.countplot(data=tips, x='day', hue='sex', order=['Sun', 'Sat', 'Thur', 'Fri'])
plt.title("Countplot with Hue and Custom Order")
plt.show()

# %%
# Example 7: Countplot with hue and custom hue order
sns.countplot(data=tips, x='day', hue='sex', hue_order=['Female', 'Male'])
plt.title("Countplot with Hue and Custom Hue Order")
plt.show()

# %%
# Example 8: Countplot with hue and stacked bars
sns.countplot(data=tips, x='day', hue='sex', dodge=False)
plt.title("Countplot with Hue and Stacked Bars")
plt.show()

# %%
# Example 9: Countplot with hue and adjusted bar width
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Hue and Adjusted Bar Width")
plt.xticks(rotation=45)
plt.show()

# %%
# Example 10: Countplot with hue and horizontal bars
sns.countplot(data=tips, y='day', hue='sex')
plt.title("Countplot with Hue and Horizontal Bars")
plt.show()

# %%
# Example 11: Countplot with hue and log scale
sns.countplot(data=tips, x='day', hue='sex')
plt.yscale("log")
plt.title("Countplot with Hue and Log Scale")
plt.show()

# %%
# Example 12: Countplot with hue and labeled bars
ax = sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Hue and Labeled Bars")
for p in ax.patches:
    ax.annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2, p.get_height()), ha="center", va="center")
plt.show()

# %%
# Example 13: Countplot with hue and rotated x-axis labels
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Hue and Rotated X-axis Labels")
plt.xticks(rotation=45)
plt.show()

# %%
# Example 14: Countplot with hue, title, and axis labels
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Hue, Title, and Axis Labels")
plt.xlabel("Day of the Week")
plt.ylabel("Count")
plt.show()

# %%
# Example 15: Countplot with hue and legend
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Hue and Legend")
plt.legend(title="Gender")
plt.show()

# %%
# Example 16: Countplot with hue and customized legend
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Hue and Customized Legend")
plt.legend(title="Gender", loc="upper right", bbox_to_anchor=(1.2, 1))
plt.show()

# %%
# Example 17: Countplot with custom hue palette
sns.countplot(data=tips, x='day', hue='sex', palette=['blue', 'red'])
plt.title("Countplot with Custom Hue Palette")
plt.show()

# %%
# Example 18: Countplot with custom bar color
sns.countplot(data=tips, x='day', color='green')
plt.title("Countplot with Custom Bar Color")
plt.show()

# %%
# Example 19: Countplot with multiple groups and hue nesting
sns.countplot(data=tips, x='day', hue='sex', dodge=True)
plt.title("Countplot with Multiple Groups and Hue Nesting")
plt.show()

# %%
# Example 20: Countplot with multiple groups and nested hue
sns.countplot(data=tips, x='day', hue='time')
plt.title("Countplot with Multiple Groups and Nested Hue")
plt.show()

# %%
# Example 21: Countplot with multiple groups and error bars
sns.countplot(data=tips, x='day', hue='sex', ci='sd')
plt.title("Countplot with Multiple Groups and Error Bars")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Example 21: Countplot with multiple groups and error bars
# ----> 2 sns.countplot(data=tips, x='day', hue='sex', ci='sd')
#       3 plt.title("Countplot with Multiple Groups and Error Bars")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
#    1587     self.annotate_axes(ax)
# ...

# %%
# Example 22: Countplot with multiple groups and capped error bars
sns.countplot(data=tips, x='day', hue='sex', ci='sd', capsize=0.1)
plt.title("Countplot with Multiple Groups and Capped Error Bars")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Example 22: Countplot with multiple groups and capped error bars
# ----> 2 sns.countplot(data=tips, x='day', hue='sex', ci='sd', capsize=0.1)
#       3 plt.title("Countplot with Multiple Groups and Capped Error Bars")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
# ...

# %%
# Example 23: Countplot with multiple groups and different cap widths
sns.countplot(data=tips, x='day', hue='sex', ci='sd', capsize=0.2)
plt.title("Countplot with Multiple Groups and Different Cap Widths")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Example 23: Countplot with multiple groups and different cap widths
# ----> 2 sns.countplot(data=tips, x='day', hue='sex', ci='sd', capsize=0.2)
#       3 plt.title("Countplot with Multiple Groups and Different Cap Widths")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
# ...

# %%
# Example 24: Countplot with multiple groups and custom palette and error bar colors
sns.countplot(data=tips, x='day', hue='sex', palette='Set2', ci='sd', errcolor='red')
plt.title("Countplot with Multiple Groups, Custom Palette, and Error Bar Colors")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Example 24: Countplot with multiple groups and custom palette and error bar colors
# ----> 2 sns.countplot(data=tips, x='day', hue='sex', palette='Set2', ci='sd', errcolor='red')
#       3 plt.title("Countplot with Multiple Groups, Custom Palette, and Error Bar Colors")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# ...

# %%
# Example 25: Countplot with multiple groups and adjusted bar width
sns.countplot(data=tips, x='day', hue='sex', ci=None)
plt.title("Countplot with Multiple Groups and Adjusted Bar Width")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Example 25: Countplot with multiple groups and adjusted bar width
# ----> 2 sns.countplot(data=tips, x='day', hue='sex', ci=None)
#       3 plt.title("Countplot with Multiple Groups and Adjusted Bar Width")
#       4 plt.xticks(rotation=45)
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
# ...

# %%
# Example 26: Countplot with multiple groups and horizontal bars
sns.countplot(data=tips, y='day', hue='sex')
plt.title("Countplot with Multiple Groups and Horizontal Bars")
plt.show()

# %%
# Example 27: Countplot with multiple groups and log scale
sns.countplot(data=tips, x='day', hue='sex')
plt.yscale("log")
plt.title("Countplot with Multiple Groups and Log Scale")
plt.show()

# %%
# Example 28: Countplot with multiple groups and labeled bars
ax = sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Multiple Groups and Labeled Bars")
for p in ax.patches:
    ax.annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2, p.get_height()), ha="center", va="center")
plt.show()

# %%
# Example 29: Countplot with multiple groups and rotated x-axis labels
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Multiple Groups and Rotated X-axis Labels")
plt.xticks(rotation=45)
plt.show()

# %%
# Example 30: Countplot with multiple groups, title, and axis labels
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Multiple Groups, Title, and Axis Labels")
plt.xlabel("Day of the Week")
plt.ylabel("Count")
plt.show()

# %%
# Example 31: Countplot with multiple groups and legend
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Multiple Groups and Legend")
plt.legend(title="Gender")
plt.show()

# %%
# Example 32: Countplot with multiple groups and customized legend
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Multiple Groups and Customized Legend")
plt.legend(title="Gender", loc="upper right", bbox_to_anchor=(1.2, 1))
plt.show()

# %%
# Example 33: Countplot with custom hue palette
sns.countplot(data=tips, x='day', hue='sex', palette=['blue', 'red'])
plt.title("Countplot with Custom Hue Palette")
plt.show()

# %%
# Example 34: Countplot with custom bar color
sns.countplot(data=tips, x='day', color='green')
plt.title("Countplot with Custom Bar Color")
plt.show()

# %%
# Example 35: Countplot with multiple groups and hue nesting
sns.countplot(data=tips, x='day', hue='sex', dodge=True)
plt.title("Countplot with Multiple Groups and Hue Nesting")
plt.show()

# %%
# Example 36: Countplot with multiple groups and nested hue
sns.countplot(data=tips, x='day', hue='time')
plt.title("Countplot with Multiple Groups and Nested Hue")
plt.show()

# %%
# Example 37: Countplot with multiple groups and error bars
sns.countplot(data=tips, x='day', hue='sex', ci='sd')
plt.title("Countplot with Multiple Groups and Error Bars")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Example 37: Countplot with multiple groups and error bars
# ----> 2 sns.countplot(data=tips, x='day', hue='sex', ci='sd')
#       3 plt.title("Countplot with Multiple Groups and Error Bars")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
#    1587     self.annotate_axes(ax)
# ...

# %%
# Example 38: Countplot with multiple groups and capped error bars
sns.countplot(data=tips, x='day', hue='sex', ci='sd', capsize=0.1)
plt.title("Countplot with Multiple Groups and Capped Error Bars")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Example 38: Countplot with multiple groups and capped error bars
# ----> 2 sns.countplot(data=tips, x='day', hue='sex', ci='sd', capsize=0.1)
#       3 plt.title("Countplot with Multiple Groups and Capped Error Bars")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
# ...

# %%
# Example 39: Countplot with multiple groups and different cap widths
sns.countplot(data=tips, x='day', hue='sex', ci='sd', capsize=0.2)
plt.title("Countplot with Multiple Groups and Different Cap Widths")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 2
#       1 # Example 39: Countplot with multiple groups and different cap widths
# ----> 2 sns.countplot(data=tips, x='day', hue='sex', ci='sd', capsize=0.2)
#       3 plt.title("Countplot with Multiple Groups and Different Cap Widths")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
# ...

# %%
# Example 40: Countplot with multiple groups and custom palette and error bar colors
sns.countplot(data=tips, x='day', hue='sex', palette='Set2', ci='sd', errcolor='red')
plt.title("Countplot with Multiple Groups, Custom Palette, and Error Bar Colors")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 2
#       1 # Example 40: Countplot with multiple groups and custom palette and error bar colors
# ----> 2 sns.countplot(data=tips, x='day', hue='sex', palette='Set2', ci='sd', errcolor='red')
#       3 plt.title("Countplot with Multiple Groups, Custom Palette, and Error Bar Colors")
#       4 plt.show()
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# ...

# %%
# Example 41: Countplot with multiple groups and adjusted bar width
sns.countplot(data=tips, x='day', hue='sex', ci=None)
plt.title("Countplot with Multiple Groups and Adjusted Bar Width")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 # Example 41: Countplot with multiple groups and adjusted bar width
# ----> 2 sns.countplot(data=tips, x='day', hue='sex', ci=None)
#       3 plt.title("Countplot with Multiple Groups and Adjusted Bar Width")
#       4 plt.xticks(rotation=45)
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File c:\Program Files\Python311\Lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
# ...

# %%
# Example 42: Countplot with multiple groups and horizontal bars
sns.countplot(data=tips, y='day', hue='sex')
plt.title("Countplot with Multiple Groups and Horizontal Bars")
plt.show()

# %%
# Example 43: Countplot with multiple groups and log scale
sns.countplot(data=tips, x='day', hue='sex')
plt.yscale("log")
plt.title("Countplot with Multiple Groups and Log Scale")
plt.show()

# %%
# Example 44: Countplot with multiple groups and labeled bars
ax = sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Multiple Groups and Labeled Bars")
for p in ax.patches:
    ax.annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2, p.get_height()), ha="center", va="center")
plt.show()

# %%
# Example 45: Countplot with multiple groups and rotated x-axis labels
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Multiple Groups and Rotated X-axis Labels")
plt.xticks(rotation=45)
plt.show()

# %%
# Example 46: Countplot with multiple groups, title, and axis labels
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Multiple Groups, Title, and Axis Labels")
plt.xlabel("Day of the Week")
plt.ylabel("Count")
plt.show()

# %%
# Example 47: Countplot with multiple groups and legend
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Multiple Groups and Legend")
plt.legend(title="Gender")
plt.show()

# %%
# Example 48: Countplot with multiple groups and customized legend
sns.countplot(data=tips, x='day', hue='sex')
plt.title("Countplot with Multiple Groups and Customized Legend")
plt.legend(title="Gender", loc="upper right", bbox_to_anchor=(1.2, 1))
plt.show()

# %%
# Example 49: Countplot with custom hue palette
sns.countplot(data=tips, x='day', hue='sex', palette=['blue', 'red'])
plt.title("Countplot with Custom Hue Palette")
plt.show()

# %%
# Example 50: Countplot with custom bar color
sns.countplot(data=tips, x='day', color='green')
plt.title("Countplot with Custom Bar Color")
plt.show()
