# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load a pre-built dataset from Seaborn
df = sns.load_dataset("tips")

# %%
# Example 1: Basic barplot
sns.barplot(data=df, x="day", y="total_bill")
plt.title("Basic Barplot")
plt.show()

# %%
# Example 2: Barplot with hue
sns.barplot(data=df, x="day", y="total_bill", hue="sex")
plt.title("Barplot with Hue")
plt.show()

# %%
# Example 3: Barplot with custom order
sns.barplot(data=df, x="day", y="total_bill", order=["Sun", "Sat", "Fri", "Thur"])
plt.title("Barplot with Custom Order")
plt.show()

# %%
# Example 4: Barplot with custom palette
sns.barplot(data=df, x="day", y="total_bill", palette="Set2")
plt.title("Barplot with Custom Palette")
plt.show()

# %%
# Example 5: Barplot with custom estimator
sns.barplot(data=df, x="day", y="total_bill", estimator=max)
plt.title("Barplot with Custom Estimator")
plt.show()

# %%
# Example 6: Barplot with confidence intervals
sns.barplot(data=df, x="day", y="total_bill", ci=68)
plt.title("Barplot with Confidence Intervals")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\2981789105.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", ci=68)

# %%
# Example 7: Barplot with error bars
sns.barplot(data=df, x="day", y="total_bill", ci="sd")
plt.title("Barplot with Error Bars")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\3811723372.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", ci="sd")

# %%
# Example 8: Barplot with capped error bars
sns.barplot(data=df, x="day", y="total_bill", ci="sd", capsize=0.2)
plt.title("Barplot with Capped Error Bars")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\1285192744.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", ci="sd", capsize=0.2)

# %%
# Example 9: Barplot with different cap widths
sns.barplot(data=df, x="day", y="total_bill", ci="sd", capsize=0.1)
plt.title("Barplot with Different Cap Widths")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\2717111348.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", ci="sd", capsize=0.1)

# %%
# Example 10: Barplot with custom palette and error bar colors
sns.barplot(data=df, x="day", y="total_bill", palette="Set2", ci="sd", errcolor="red")
plt.title("Barplot with Custom Palette and Error Bar Colors")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\444359329.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", palette="Set2", ci="sd", errcolor="red")

# %%
# Example 11: Barplot with grouped bars
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=None)
plt.title("Barplot with Grouped Bars")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\2117929604.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=None)

# %%
# Example 12: Barplot with stacked bars
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=None, dodge=False)
plt.title("Barplot with Stacked Bars")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\2170314186.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=None, dodge=False)

# %%
# Example 13: Barplot with adjusted bar width
sns.barplot(data=df, x="day", y="total_bill", ci=None)
plt.title("Barplot with Adjusted Bar Width")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\3327914694.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", ci=None)

# %%
# Example 14: Barplot with horizontal bars
sns.barplot(data=df, y="day", x="total_bill")
plt.title("Barplot with Horizontal Bars")
plt.show()

# %%
# Example 15: Barplot with log scale
sns.barplot(data=df, x="day", y="total_bill")
plt.yscale("log")
plt.title("Barplot with Log Scale")
plt.show()

# %%
# Example 16: Barplot with labeled bars
ax = sns.barplot(data=df, x="day", y="total_bill")
plt.title("Barplot with Labeled Bars")
for p in ax.patches:
    ax.annotate(f"{p.get_height():.2f}", (p.get_x() + p.get_width() / 2, p.get_height()), ha="center", va="center")
plt.show()

# %%
# Example 17: Barplot with rotated x-axis labels
sns.barplot(data=df, x="day", y="total_bill")
plt.title("Barplot with Rotated X-axis Labels")
plt.xticks(rotation=45)
plt.show()

# %%
# Example 18: Barplot with title and axis labels
sns.barplot(data=df, x="day", y="total_bill")
plt.title("Barplot with Title and Axis Labels")
plt.xlabel("Day of the Week")
plt.ylabel("Total Bill")
plt.show()

# %%
# Example 19: Barplot with legend
sns.barplot(data=df, x="day", y="total_bill", hue="sex")
plt.title("Barplot with Legend")
plt.legend(title="Gender")
plt.show()

# %%
# Example 20: Barplot with customized legend
sns.barplot(data=df, x="day", y="total_bill", hue="sex")
plt.title("Barplot with Customized Legend")
plt.legend(title="Gender", loc="upper right", bbox_to_anchor=(1.2, 1))
plt.show()

# %%
# Example 21: Barplot with hue and custom order
sns.barplot(data=df, x="day", y="total_bill", hue="sex", order=["Sun", "Sat", "Fri", "Thur"])
plt.title("Barplot with Hue and Custom Order")
plt.show()

# %%
# Example 22: Barplot with hue and custom palette
sns.barplot(data=df, x="day", y="total_bill", hue="sex", palette="Set2")
plt.title("Barplot with Hue and Custom Palette")
plt.show()

# %%
# Example 23: Barplot with hue and custom estimator
sns.barplot(data=df, x="day", y="total_bill", hue="sex", estimator=max)
plt.title("Barplot with Hue and Custom Estimator")
plt.show()

# %%
# Example 24: Barplot with hue and confidence intervals
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=68)
plt.title("Barplot with Hue and Confidence Intervals")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\1032408242.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=68)

# %%
# Example 25: Barplot with hue and error bars
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd")
plt.title("Barplot with Hue and Error Bars")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\68903405.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd")

# %%
# Example 26: Barplot with hue and capped error bars
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd", capsize=0.2)
plt.title("Barplot with Hue and Capped Error Bars")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\387053039.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd", capsize=0.2)

# %%
# Example 27: Barplot with hue and different cap widths
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd", capsize=0.1)
plt.title("Barplot with Hue and Different Cap Widths")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\1934970741.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd", capsize=0.1)

# %%
# Example 28: Barplot with hue and custom palette and error bar colors
sns.barplot(data=df, x="day", y="total_bill", hue="sex", palette="Set2", ci="sd", errcolor="red")
plt.title("Barplot with Hue, Custom Palette, and Error Bar Colors")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\646269747.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", palette="Set2", ci="sd", errcolor="red")

# %%
# Example 29: Barplot with hue, grouped bars, and custom order
sns.barplot(data=df, x="day", y="total_bill", hue="sex", order=["Sun", "Sat", "Fri", "Thur"], ci=None)
plt.title("Barplot with Hue, Grouped Bars, and Custom Order")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\3232915232.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", order=["Sun", "Sat", "Fri", "Thur"], ci=None)

# %%
# Example 30: Barplot with hue, stacked bars, and custom palette
sns.barplot(data=df, x="day", y="total_bill", hue="sex", palette="Set2", ci=None, dodge=False)
plt.title("Barplot with Hue, Stacked Bars, and Custom Palette")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\2090209643.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", palette="Set2", ci=None, dodge=False)

# %%
# Example 31: Barplot with hue and adjusted bar width
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=None)
plt.title("Barplot with Hue and Adjusted Bar Width")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\3249015682.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=None)

# %%
# Example 32: Barplot with hue and horizontal bars
sns.barplot(data=df, y="day", x="total_bill", hue="sex")
plt.title("Barplot with Hue and Horizontal Bars")
plt.show()

# %%
# Example 33: Barplot with hue and log scale
sns.barplot(data=df, x="day", y="total_bill", hue="sex")
plt.yscale("log")
plt.title("Barplot with Hue and Log Scale")
plt.show()

# %%
# Example 34: Barplot with hue and labeled bars
ax = sns.barplot(data=df, x="day", y="total_bill", hue="sex")
plt.title("Barplot with Hue and Labeled Bars")
for p in ax.patches:
    ax.annotate(f"{p.get_height():.2f}", (p.get_x() + p.get_width() / 2, p.get_height()), ha="center", va="center")
plt.show()

# %%
# Example 35: Barplot with hue and rotated x-axis labels
sns.barplot(data=df, x="day", y="total_bill", hue="sex")
plt.title("Barplot with Hue and Rotated X-axis Labels")
plt.xticks(rotation=45)
plt.show()

# %%
# Example 36: Barplot with hue, title, and axis labels
sns.barplot(data=df, x="day", y="total_bill", hue="sex")
plt.title("Barplot with Hue, Title, and Axis Labels")
plt.xlabel("Day of the Week")
plt.ylabel("Total Bill")
plt.show()

# %%
# Example 37: Barplot with hue and legend
sns.barplot(data=df, x="day", y="total_bill", hue="sex")
plt.title("Barplot with Hue and Legend")
plt.legend(title="Gender")
plt.show()

# %%
# Example 38: Barplot with hue and customized legend
sns.barplot(data=df, x="day", y="total_bill", hue="sex")
plt.title("Barplot with Hue and Customized Legend")
plt.legend(title="Gender", loc="upper right", bbox_to_anchor=(1.2, 1))
plt.show()

# %%
# Example 40: Barplot with custom error bars using a DataFrame
err_df = df.groupby("day")["total_bill"].std().reset_index()
sns.barplot(data=df, x="day", y="total_bill", ci=None)
plt.errorbar(x=err_df["day"], y=err_df["total_bill"], yerr=err_df["total_bill"], fmt="none", color="red")
plt.title("Barplot with Custom Error Bars using a DataFrame")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\2225907345.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", ci=None)

# %%
# Example 41: Barplot with multiple groups and hue nesting
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=None, dodge=False)
plt.title("Barplot with Multiple Groups and Hue Nesting")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\3112756485.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=None, dodge=False)

# %%
# Example 42: Barplot with multiple groups and nested hue
sns.barplot(data=df, x="day", y="total_bill", hue="time", ci=None)
plt.title("Barplot with Multiple Groups and Nested Hue")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\969960322.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="time", ci=None)

# %%
# Example 43: Barplot with multiple groups and error bars
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd")
plt.title("Barplot with Multiple Groups and Error Bars")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\346626244.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd")

# %%
# Example 44: Barplot with multiple groups and capped error bars
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd", capsize=0.2)
plt.title("Barplot with Multiple Groups and Capped Error Bars")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\2241724558.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd", capsize=0.2)

# %%
# Example 45: Barplot with multiple groups and different cap widths
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd", capsize=0.1)
plt.title("Barplot with Multiple Groups and Different Cap Widths")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\172727031.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci="sd", capsize=0.1)

# %%
# Example 46: Barplot with multiple groups and custom palette and error bar colors
sns.barplot(data=df, x="day", y="total_bill", hue="sex", palette="Set2", ci="sd", errcolor="red")
plt.title("Barplot with Multiple Groups, Custom Palette, and Error Bar Colors")
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\2758520658.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", palette="Set2", ci="sd", errcolor="red")

# %%
# Example 47: Barplot with multiple groups and adjusted bar width
sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=None)
plt.title("Barplot with Multiple Groups and Adjusted Bar Width")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\rvign\AppData\Local\Temp\ipykernel_22788\3420676139.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="day", y="total_bill", hue="sex", ci=None)

# %%
# Example 48: Barplot with multiple groups and horizontal bars
sns.barplot(data=df, y="day", x="total_bill", hue="sex")
plt.title("Barplot with Multiple Groups and Horizontal Bars")
plt.show()

# %%
# Example 49: Barplot with multiple groups and log scale
sns.barplot(data=df, x="day", y="total_bill", hue="sex")
plt.yscale("log")
plt.title("Barplot with Multiple Groups and Log Scale")
plt.show()

# %%
# Example 50: Barplot with multiple groups and labeled bars
ax = sns.barplot(data=df, x="day", y="total_bill", hue="sex")
plt.title("Barplot with Multiple Groups and Labeled Bars")
for p in ax.patches:
    ax.annotate(f"{p.get_height():.2f}", (p.get_x() + p.get_width() / 2, p.get_height()), ha="center", va="center")
plt.show()
